# %%
# %matplotlib inline

# %%
from __future__ import print_function
import pickle
import re
import requests
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# # Load Codelists

# %%
sector_url = 'http://iatistandard.org/202/codelists/downloads/clv3/json/en/Sector.json'
sectors_json = requests.get(sector_url).json()['data']
sectors = {
    item['code']: item for item in sectors_json
}

# %%
sectors
# Out:
# {'11110': {'category': '111',
#   'code': '11110',
#   'description': 'Education sector policy, planning and programmes; aid to education ministries, administration and management systems; institution capacity building and advice; school management and governance; curriculum and materials development; unspecified education activities.',
#   'name': 'Education policy and administrative management'},
#  '11120': {'category': '111',
#   'code': '11120',
#   'description': 'Educational buildings, equipment, materials; subsidiary services to education (boarding facilities, staff housing); language training; colloquia, seminars, lectures, etc.',
#   'name': 'Education facilities and training'},
#  '11130': {'category': '111',
#   'code': '11130',
#   'description': 'Teacher education (where the level of education is unspecified); in-service and pre-service training; materials development.',
#   'name': 'Teacher training'},
#  '11182': {'category': '111',
#   'code': '11182',
#   'description': 'Research and studies on education effectiveness, relevance and quality; systematic evaluation and monitoring.',
#   'name': 'Educational research'},
#  '11220': {'category': '112',
#   'code': '11220',
#   'description': 'Formal and non-formal primary education for children; all elementary and first cycle systematic instruction; provision of learning materials.',
#   'name': 'Primary education'},
#  '11230': {'category': '112',
#   'code': '11230',
#   'description': 'Formal and non-formal education for basic life skills for young people and adults (adults education); literacy and numeracy training.',
#   'name': 'Basic life skills for youth and adults'},
#  '11231': {'category': '112',
#   'code': '11231',
#   'description': 'Formal and non-formal education for basic life skills for young people.',
#   'name': 'Basic life skills for youth'},
#  '11232': {'category': '112',
#   'code': '11232',
#   'description': 'Formal primary education for adults.',
#   'name': 'Primary education equivalent for adults'},
#  '11240': {'category': '112',
#   'code': '11240',
#   'description': 'Formal and non-formal pre-school education.',
#   'name': 'Early childhood education'},
#  '11320': {'category': '113',
#   'code': '11320',
#   'description': 'Second cycle systematic instruction at both junior and senior levels.',
#   'name': 'Secondary education'},
#  '11321': {'category': '113',
#   'code': '11321',
#   'description': 'Second cycle systematic instruction at junior level.',
#   'name': 'Lower secondary education'},
#  '11322': {'category': '113',
#   'code': '11322',
#   'description': 'Second cycle systematic instruction at senior level.',
#   'name': 'Upper secondary education'},
#  '11330': {'category': '113',
#   'code': '11330',
#   'description': 'Elementary vocational training and secondary level technical education; on-the job training; apprenticeships; including informal vocational training.',
#   'name': 'Vocational training'},
#  '11420': {'category': '114',
#   'code': '11420',
#   'description': 'Degree and diploma programmes at universities, colleges and polytechnics; scholarships.',
#   'name': 'Higher education'},
#  '11430': {'category': '114',
#   'code': '11430',
#   'description': 'Professional-level vocational training programmes and in-service training.',
#   'name': 'Advanced technical and managerial training'},
#  '12110': {'category': '121',
#   'code': '12110',
#   'description': 'Health sector policy, planning and programmes; aid to health ministries, public health administration; institution capacity building and advice; medical insurance programmes; unspecified health activities.',
#   'name': 'Health policy and administrative management'},
#  '12181': {'category': '121',
#   'code': '12181',
#   'description': 'Medical education and training for tertiary level services.',
#   'name': 'Medical education/training'},
#  '12182': {'category': '121',
#   'code': '12182',
#   'description': 'General medical research (excluding basic health research).',
#   'name': 'Medical research'},
#  '12191': {'category': '121',
#   'code': '12191',
#   'description': 'Laboratories, specialised clinics and hospitals (including equipment and supplies); ambulances; dental services; mental health care; medical rehabilitation; control of non-infectious diseases; drug and substance abuse control [excluding narcotics traffic control (16063)].',
#   'name': 'Medical services'},
#  '12220': {'category': '122',
#   'code': '12220',
#   'description': 'Basic and primary health care programmes; paramedical and nursing care programmes; supply of drugs, medicines and vaccines related to basic health care.',
#   'name': 'Basic health care'},
#  '12230': {'category': '122',
#   'code': '12230',
#   'description': 'District-level hospitals, clinics and dispensaries and related medical equipment; excluding specialised hospitals and clinics (12191).',
#   'name': 'Basic health infrastructure'},
#  '12240': {'category': '122',
#   'code': '12240',
#   'description': 'Direct feeding programmes (maternal feeding, breastfeeding and weaning foods, child feeding, school feeding); determination of micro-nutrient deficiencies; provision of vitamin A, iodine, iron etc.; monitoring of nutritional status; nutrition and food hygiene education; household food security.',
#   'name': 'Basic nutrition'},
#  '12250': {'category': '122',
#   'code': '12250',
#   'description': 'Immunisation; prevention and control of infectious and parasite diseases, except malaria (12262), tuberculosis (12263), HIV/AIDS and other STDs (13040). It includes diarrheal diseases, vector-borne diseases (e.g. river blindness and guinea worm), viral diseases, mycosis, helminthiasis, zoonosis, diseases by other bacteria and viruses, pediculosis, etc.',
#   'name': 'Infectious disease control'},
#  '12261': {'category': '122',
#   'code': '12261',
#   'description': 'Information, education and training of the population for improving health knowledge and practices; public health and awareness campaigns; promotion of improved personal hygiene practices, including use of sanitation facilities and handwashing with soap.',
#   'name': 'Health education'},
#  '12262': {'category': '122',
#   'code': '12262',
#   'description': 'Prevention and control of malaria.',
#   'name': 'Malaria control'},
#  '12263': {'category': '122',
#   'code': '12263',
#   'description': 'Immunisation, prevention and control of tuberculosis.',
#   'name': 'Tuberculosis control'},
#  '12281': {'category': '122',
#   'code': '12281',
#   'description': 'Training of health staff for basic health care services.',
#   'name': 'Health personnel development'},
#  '13010': {'category': '130',
#   'code': '13010',
#   'description': 'Population/development policies; census work, vital registration; migration data; demographic research/analysis; reproductive health research; unspecified population activities.',
#   'name': 'Population policy and administrative management'},
#  '13020': {'category': '130',
#   'code': '13020',
#   'description': 'Promotion of reproductive health; prenatal and postnatal care including delivery; prevention and treatment of infertility; prevention and management of consequences of abortion; safe motherhood activities.',
#   'name': 'Reproductive health care'},
#  '13030': {'category': '130',
#   'code': '13030',
#   'description': 'Family planning services including counselling; information, education and communication (IEC) activities; delivery of contraceptives; capacity building and training.',
#   'name': 'Family planning'},
#  '13040': {'category': '130',
#   'code': '13040',
#   'description': 'All activities related to sexually transmitted diseases and HIV/AIDS control e.g. information, education and communication; testing; prevention; treatment, care.',
#   'name': 'STD control including HIV/AIDS'},
#  '13081': {'category': '130',
#   'code': '13081',
#   'description': 'Education and training of health staff for population and reproductive health care services.',
#   'name': 'Personnel development for population and reproductive health'},
#  '14010': {'category': '140',
#   'code': '14010',
#   'description': 'Water sector policy and governance, including legislation, regulation, planning and management as well as transboundary management of water; institutional capacity development; activities supporting the Integrated Water Resource Management approach (IWRM: see box below).',
#   'name': 'Water sector policy and administrative management'},
#  '14015': {'category': '140',
#   'code': '14015',
#   'description': 'Collection and usage of quantitative and qualitative data on water resources; creation and sharing of water knowledge; conservation and rehabilitation of inland surface waters (rivers, lakes etc.), ground water and coastal waters; prevention of water contamination.',
#   'name': 'Water resources conservation (including data collection)'},
#  '14020': {'category': '140',
#   'code': '14020',
#   'description': 'Programmes where components according to 14021 and 14022 cannot be identified. When components are known, they should individually be reported under their respective purpose codes: water supply (14021), sanitation (14022), and hygiene (12261).',
#   'name': 'Water supply and sanitation - large systems'},
#  '14021': {'category': '140',
#   'code': '14021',
#   'description': 'Potable water treatment plants; intake works; storage; water supply pumping stations; large scale transmission / conveyance and distribution systems.',
#   'name': 'Water supply - large systems'},
#  '14022': {'category': '140',
#   'code': '14022',
#   'description': 'Large scale sewerage including trunk sewers and sewage pumping stations; domestic and industrial waste water treatment plants.',
#   'name': 'Sanitation - large systems'},
#  '14030': {'category': '140',
#   'code': '14030',
#   'description': 'Programmes where components according to 14031 and 14032 cannot be identified. When components are known, they should individually be reported under their respective purpose codes: water supply (14031), sanitation (14032), and hygiene (12261).',
#   'name': 'Basic drinking water supply and basic sanitation'},
#  '14031': {'category': '140',
#   'code': '14031',
#   'description': 'Rural water supply schemes using handpumps, spring catchments, gravity-fed systems, rainwater collection and fog harvesting, storage tanks, small distribution systems typically with shared connections/points of use. Urban schemes using handpumps and local neighbourhood networks including those with shared connections.',
#   'name': 'Basic drinking water supply'},
#  '14032': {'category': '140',
#   'code': '14032',
#   'description': 'Latrines, on-site disposal and alternative sanitation systems, including the promotion of household and community investments in the construction of these facilities. (Use code 12261 for activities promoting improved personal hygiene practices.)',
#   'name': 'Basic sanitation'},
#  '14040': {'category': '140',
#   'code': '14040',
#   'description': 'Infrastructure-focused integrated river basin projects and related institutional activities; river flow control; dams and reservoirs [excluding dams primarily for irrigation (31140) and hydropower (23220) and activities related to river transport (21040)].',
#   'name': 'River basins’ development'},
#  '14050': {'category': '140',
#   'code': '14050',
#   'description': 'Municipal and industrial solid waste management, including hazardous and toxic waste; collection, disposal and treatment; landfill areas; composting and reuse.',
#   'name': 'Waste management / disposal'},
#  '14081': {'category': '140',
#   'code': '14081',
#   'description': 'Education and training for sector professionals and service providers.',
#   'name': 'Education and training in water supply and sanitation'},
#  '15110': {'category': '151',
#   'code': '15110',
#   'description': 'Institution-building assistance to strengthen core public sector management systems and capacities. This includes macro-economic and other policy management, co-ordination, planning and reform; human resource management; organisational development; civil service reform; e-government; development planning, monitoring and evaluation; support to ministries involved in aid co-ordination; other ministries and government departments when sector cannot be specified. (Use specific sector codes for development of systems and capacities in sector ministries.)',
#   'name': 'Public sector policy and administrative management'},
#  '15111': {'category': '151',
#   'code': '15111',
#   'description': 'Fiscal policy and planning; support to ministries of finance; strengthening financial and managerial accountability; public expenditure management; improving financial management systems; budget drafting; inter-governmental fiscal relations, public audit, public debt. (Use code 15114 for domestic revenue mobilisation and code 33120 for customs).',
#   'name': 'Public Finance Management (PFM)'},
#  '15112': {'category': '151',
#   'code': '15112',
#   'description': 'Decentralisation processes (including political, administrative and fiscal dimensions); intergovernmental relations and federalism; strengthening departments of regional and local government, regional and local authorities and their national associations. (Use specific sector codes for decentralisation of sector management and services.)',
#   'name': 'Decentralisation and support to subnational government'},
#  '15113': {'category': '151',
#   'code': '15113',
#   'description': 'Specialised organisations, institutions and frameworks for the prevention of and combat against corruption, bribery, money- laundering and other aspects of organised crime, with or without law enforcement powers, e.g. anti-corruption commissions and monitoring bodies, special investigation services, institutions and initiatives of integrity and ethics oversight, specialised NGOs, other civil society and citizens’ organisations directly concerned with corruption.',
#   'name': 'Anti-corruption organisations and institutions'},
#  '15114': {'category': '151',
#   'code': '15114',
#   'description': 'Support to domestic revenue mobilisation/tax policy, analysis and administration as well as non-tax public revenue, which includes work with ministries of finance, line ministries, revenue authorities or other local, regional or national public bodies. (Use code 16010 for social security and other social protection.)',
#   'name': 'Domestic Revenue Mobilisation'},
#  '15116': {'category': '151',
#   'code': '15116',
#   'description': 'Operation of the inland revenue authority.',
#   'name': 'Tax collection'},
#  '15117': {'category': '151',
#   'code': '15117',
#   'description': 'Operation of the budget office and planning as part of the budget process.',
#   'name': 'Budget planning'},
#  '15118': {'category': '151',
#   'code': '15118',
#   'description': 'Operation of the accounting and audit services.',
#   'name': 'National audit'},
#  '15119': {'category': '151',
#   'code': '15119',
#   'description': 'Management of public debt and foreign aid received (in the partner country). For reporting on debt reorganisation, use codes 600xx.',
#   'name': 'Debt and aid management'},
#  '15120': {'category': '151',
#   'code': '15120',
#   'description': 'Strengthening financial and managerial accountability; public expenditure management; improving financial management systems; tax assessment procedures; budget drafting; field auditing; measures against waste, fraud and corruption.',
#   'name': 'Public sector financial management'},
#  '15121': {'category': '151',
#   'code': '15121',
#   'description': 'Administration of external affairs and services.',
#   'name': 'Foreign affairs'},
#  '15122': {'category': '151',
#   'code': '15122',
#   'description': 'Operation of diplomatic and consular missions stationed abroad or at offices of international organisations.',
#   'name': 'Diplomatic missions'},
#  '15123': {'category': '151',
#   'code': '15123',
#   'description': "Support to administration of developing countries' foreign aid (including triangular and south-south cooperation).",
#   'name': "Administration of developing countries' foreign aid"},
#  '15124': {'category': '151',
#   'code': '15124',
#   'description': 'Administration and operation of the civil service including policies, procedures and regulations.',
#   'name': 'General personnel services'},
#  '15125': {'category': '151',
#   'code': '15125',
#   'description': 'Administration and operation of centralised supply and purchasing services.',
#   'name': 'Central procurement'},
#  '15126': {'category': '151',
#   'code': '15126',
#   'description': 'Maintenance and storage of government records and archives, operation of government-owned or occupied buildings, central motor vehicle pools, government-operated printing offices, centralised computer and data processing services, etc.',
#   'name': 'Other general public services'},
#  '15127': {'category': '151',
#   'code': '15127',
#   'description': 'Operation or support of institutions providing national monitoring and evaluation.',
#   'name': 'National monitoring and evaluation'},
#  '15128': {'category': '151',
#   'code': '15128',
#   'description': 'Financial transfers to local government; support to institutions managing such transfers. (Use specific sector codes for sector-related transfers.)',
#   'name': 'Local government finance'},
#  '15129': {'category': '151',
#   'code': '15129',
#   'description': 'Transfers to non sector-specific autonomous bodies or state-owned enterprises outside of local government finance; support to institutions managing such transfers. (Use specific sector codes for sector-related transfers.)',
#   'name': 'Other central transfers to institutions'},
#  '15130': {'category': '151',
#   'code': '15130',
#   'description': 'Support to institutions, systems and procedures of the justice sector, both formal and informal; support to ministries of justice, the interior and home affairs; judges and courts; legal drafting services; bar and lawyers associations; professional legal education; maintenance of law and order and public safety; border management; law enforcement agencies, police, prisons and their supervision; ombudsmen; alternative dispute resolution, arbitration and mediation; legal aid and counsel; traditional, indigenous and paralegal practices that fall outside the formal legal system. Measures that support the improvement of legal frameworks, constitutions, laws and regulations; legislative and constitutional drafting and review; legal reform; integration of formal and informal systems of law. Public legal education; dissemination of information on entitlements and remedies for injustice; awareness campaigns. (Use codes 152xx for activities that are primarily aimed at supporting security system reform or undertaken in connection with post-conflict and peace building activities.)',
#   'name': 'Legal and judicial development'},
#  '15131': {'category': '151',
#   'code': '15131',
#   'description': 'Judicial law and order sectors; policy development within ministries of justice or equivalents.',
#   'name': 'Justice, law and order policy, planning and administration'},
#  '15132': {'category': '151',
#   'code': '15132',
#   'description': 'Police affairs and services.',
#   'name': 'Police'},
#  '15133': {'category': '151',
#   'code': '15133',
#   'description': 'Fire-prevention and fire-fighting affairs and services.',
#   'name': 'Fire and rescue services'},
#  '15134': {'category': '151',
#   'code': '15134',
#   'description': 'Civil and criminal law courts and the judicial system, including enforcement of fines and legal settlements imposed by the courts and operation of parole and probation systems.',
#   'name': 'Judicial affairs'},
#  '15135': {'category': '151',
#   'code': '15135',
#   'description': 'Independent service representing the interests of the public by investigating and addressing complaints of unfair treatment or maladministration.',
#   'name': 'Ombudsman'},
#  '15136': {'category': '151',
#   'code': '15136',
#   'description': 'Immigration affairs and services, including alien registration, issuing work and travel documents to immigrants.',
#   'name': 'Immigration'},
#  '15137': {'category': '151',
#   'code': '15137',
#   'description': None,
#   'name': 'Prisons'},
#  '15140': {'category': '151',
#   'code': '15140',
#   'description': 'Systems of government including parliament, local government, decentralisation; civil service and civil service reform. Including general services by government (or commissioned by government) not elsewhere specified e.g. police, fire protection; cartography, meteorology, legal metrology, aerial surveys and remote sensing; administrative buildings.',
#   'name': 'Government administration'},
#  '15142': {'category': '151',
#   'code': '15142',
#   'description': 'Macroeconomic policy development and implementation.',
#   'name': 'Macroeconomic policy'},
#  '15143': {'category': '151',
#   'code': '15143',
#   'description': 'Operation or support of institutions dealing with weather forecasting.',
#   'name': 'Meteorological services'},
#  '15144': {'category': '151',
#   'code': '15144',
#   'description': 'Operation or support of institutions dealing with national standards development. (Use code 16062 for statistical capacity-building.)',
#   'name': 'National standards development'},
#  '15150': {'category': '151',
#   'code': '15150',
#   'description': 'Support to the exercise of democracy and diverse forms of participation of citizens beyond elections (15151); direct democracy instruments such as referenda and citizens’ initiatives; support to organisations to represent and advocate for their members, to monitor, engage and hold governments to account, and to help citizens learn to act in the public sphere; curricula and teaching for civic education at various levels. (This purpose code is restricted to activities targeting governance issues. When assistance to civil society is for non-governance purposes use other appropriate purpose codes.)',
#   'name': 'Democratic participation and civil society'},
#  '15151': {'category': '151',
#   'code': '15151',
#   'description': "Electoral management bodies and processes, election observation, voters' education. (Use code 15230 when in the context of an international peacekeeping operation).",
#   'name': 'Elections'},
#  '15152': {'category': '151',
#   'code': '15152',
#   'description': 'Assistance to strengthen key functions of legislatures/ parliaments including subnational assemblies and councils (representation; oversight; legislation), such as improving the capacity of legislative bodies, improving legislatures’ committees and administrative procedures,; research and information management systems; providing training programmes for legislators and support personnel. Assistance to political parties and strengthening of party systems.',
#   'name': 'Legislatures and political parties'},
#  '15153': {'category': '151',
#   'code': '15153',
#   'description': 'Activities that support free and uncensored flow of information on public issues; activities that increase the editorial and technical skills and the integrity of the print and broadcast media, e.g. training of journalists. (Use codes 22010-22040 for provision of equipment and capital assistance to media.)',
#   'name': 'Media and free flow of information'},
#  '15154': {'category': '151',
#   'code': '15154',
#   'description': 'Administration, operation or support of executive office. Includes office of the chief executive at all levels of government (monarch, governor-general, president, prime minister, governor, mayor, etc.).',
#   'name': 'Executive office'},
#  '15155': {'category': '151',
#   'code': '15155',
#   'description': None,
#   'name': 'Tax policy and administration support'},
#  '15156': {'category': '151',
#   'code': '15156',
#   'description': 'Non-tax public revenue, which includes line ministries, revenue authorities or other local, regional or national public bodies.',
#   'name': 'Other non-tax revenue mobilisation'},
#  '15160': {'category': '151',
#   'code': '15160',
#   'description': 'Measures to support specialised official human rights institutions and mechanisms at universal, regional, national and local levels in their statutory roles to promote and protect civil and political, economic, social and cultural rights as defined in international conventions and covenants; translation of international human rights commitments into national legislation; reporting and follow-up; human rights dialogue. Human rights defenders and human rights NGOs; human rights advocacy, activism, mobilisation; awareness raising and public human rights education. Human rights programming targeting specific groups, e.g. children, persons with disabilities, migrants, ethnic, religious, linguistic and sexual minorities, indigenous people and those suffering from caste discrimination, victims of trafficking, victims of torture. (Use code 15230 when in the context of a peacekeeping operation and code 15180 for ending violence against women and girls.)',
#   'name': 'Human rights'},
#  '15161': {'category': '151',
#   'code': '15161',
#   'description': "Electoral assistance and monitoring, voters' education [other than in connection with UN peace building (15230)].",
#   'name': 'Elections'},
#  '15162': {'category': '151',
#   'code': '15162',
#   'description': 'Monitoring of human rights performance; support for national and regional human rights bodies; protection of ethnic, religious and cultural minorities [other than in connection with un peace building (15230)].',
#   'name': 'Human rights'},
#  '15163': {'category': '151',
#   'code': '15163',
#   'description': 'Uncensored flow of information on public issues, including activities that increase the professionalism, skills and integrity of the print and broadcast media (e.g. training of journalists).',
#   'name': 'Free flow of information'},
#  '15164': {'category': '151',
#   'code': '15164',
#   'description': "Support for institutions and organisations (governmental and non-governmental) working for gender equality and women's empowerment.",
#   'name': "Women's equality organisations and institutions"},
#  '15170': {'category': '151',
#   'code': '15170',
#   'description': 'Support for institutions and organisations (governmental and non-governmental) working for gender equality and women’s empowerment.',
#   'name': 'Women’s equality organisations and institutions'},
#  '15180': {'category': '151',
#   'code': '15180',
#   'description': 'Support to programmes designed to prevent and eliminate all forms of violence against women and girls/gender-based violence. This encompasses a broad range of forms of physical, sexual and psychological violence including but not limited to: intimate partner violence (domestic violence); sexual violence; female genital mutilation/cutting (FGM/C); child, early and forced marriage; acid throwing; honour killings; and trafficking of women and girls. Prevention activities may include efforts to empower women and girls; change attitudes, norms and behaviour; adopt and enact legal reforms; and strengthen implementation of laws and policies on ending violence against women and girls, including through strengthening institutional capacity. Interventions to respond to violence against women and girls/gender-based violence may include expanding access to services including legal assistance, psychosocial counselling and health care; training personnel to respond more effectively to the needs of survivors; and ensuring investigation, prosecution and punishment of perpetrators of violence.',
#   'name': 'Ending violence against women and girls'},
#  '15185': {'category': '151',
#   'code': '15185',
#   'description': 'Decentralisation processes (including political, administrative and fiscal dimensions); intergovernmental relations and federalism; strengthening local authorities.',
#   'name': 'Local government administration'},
#  '15210': {'category': '152',
#   'code': '15210',
#   'description': 'Technical co-operation provided to parliament, government ministries, law enforcement agencies and the judiciary to assist review and reform of the security system to improve democratic governance and civilian control; technical co-operation provided to government to improve civilian oversight and democratic control of budgeting, management, accountability and auditing of security expenditure, including military budgets, as part of a public expenditure management programme; assistance to civil society to enhance its competence and capacity to scrutinise the security system so that it is managed in accordance with democratic norms and principles of accountability, transparency and good governance. [Other than in the context of an international peacekeeping operation (15230).]',
#   'name': 'Security system management and reform'},
#  '15220': {'category': '152',
#   'code': '15220',
#   'description': 'Support for civilian activities related to peace building, conflict prevention and resolution, including capacity building, monitoring, dialogue and information exchange. Bilateral participation in international civilian peace missions such as those conducted by the UN Department of Political Affairs (UNDPA) or the European Union (European Security and Defence Policy), and contributions to civilian peace funds or commissions (e.g. Peacebuilding Commission, Peacebuilding thematic window of the MDG achievement fund etc.). The contributions can take the form of financing or provision of equipment or civilian or military personnel (e.g. for training civilians). (Use code 15230 for bilateral participation in international peacekeeping operations).',
#   'name': 'Civilian peace-building, conflict prevention and resolution'},
#  '15230': {'category': '152',
#   'code': '15230',
#   'description': 'Bilateral participation in peacekeeping operations mandated or authorised by the United Nations (UN) through Security Council resolutions, and conducted by international organisations, e.g. UN, NATO, the European Union (Security and Defence Policy security-related operations), or regional groupings of developing countries. Direct contributions to the UN Department for Peacekeeping Operations (UNDPKO) budget are excluded from bilateral ODA (they are reportable in part as multilateral ODA, see Annex 9). The activities that can be reported as bilateral ODA under this code are limited to: human rights and election monitoring; reintegration of demobilised soldiers; rehabilitation of basic national infrastructure; monitoring or retraining of civil administrators and police forces; security sector reform and other rule of law-related activities; training in customs and border control procedures; advice or training in fiscal or macroeconomic stabilisation policy; repatriation and demobilisation of armed factions, and disposal of their weapons; explosive mine removal. The enforcement aspects of international peacekeeping operations are not reportable as ODA. ODA-eligible bilateral participation in peacekeeping operations can take the form of financing or provision of equipment or military or civilian personnel (e.g. police officers). The reportable cost is calculated as the excess over what the personnel and equipment would have cost to maintain had they not been assigned to take part in a peace operation. Costs for military contingents participating in UNDPKO peacekeeping operations are not reportable as ODA. International peacekeeping operations may include humanitarian-type activities (contributions to the form of equipment or personnel), as described in codes 7xxxx. These should be included under code 15230 if they are an integrated part of the activities above, otherwise they should be reported as humanitarian aid.NB: When using this code, indicate the name of the operation in the short description of the activity reported.',
#   'name': 'Participation in international peacekeeping operations'},
#  '15240': {'category': '152',
#   'code': '15240',
#   'description': 'Reintegration of demobilised military personnel into the economy; conversion of production facilities from military to civilian outputs; technical co-operation to control, prevent and/or reduce the proliferation of small arms and light weapons (SALW) – see para. 80 of the Directives for definition of SALW activities covered. [Other than in the context of an international peacekeeping operation (15230) or child soldiers (15261)].',
#   'name': 'Reintegration and SALW control'},
#  '15250': {'category': '152',
#   'code': '15250',
#   'description': 'All activities related to land mines and explosive remnants of war which have benefits to developing countries as their main objective, including removal of land mines and explosive remnants of war, and stockpile destruction for developmental purposes [other than in the context of an international peacekeeping operation (15230)]; risk education and awareness raising; rehabilitation, reintegration and assistance to victims, and research and development on demining and clearance. Only activities for civilian purposes are ODA-eligible.',
#   'name': 'Removal of land mines and explosive remnants of war'},
#  '15261': {'category': '152',
#   'code': '15261',
#   'description': 'Technical co-operation provided to government – and assistance to civil society organisations – to support and apply legislation designed to prevent the recruitment of child soldiers, and to demobilise, disarm, reintegrate, repatriate and resettle (DDR) child soldiers.',
#   'name': 'Child soldiers (Prevention and demobilisation)'},
#  '16010': {'category': '160',
#   'code': '16010',
#   'description': 'Social legislation and administration; institution capacity building and advice; social security and other social schemes; special programmes for the elderly, orphans, the disabled, street children; social dimensions of structural adjustment; unspecified social infrastructure and services, including consumer protection.',
#   'name': 'Social/ welfare services'},
#  '16011': {'category': '160',
#   'code': '16011',
#   'description': 'Administration of overall social protection policies, plans, programmes and budgets including legislation, standards and statistics on social protection.',
#   'name': 'Social protection and welfare services policy, planning and administration'},
#  '16012': {'category': '160',
#   'code': '16012',
#   'description': 'Social protection shemes in the form of cash or in-kind benefits to people unable to work due to sickness or injury.',
#   'name': 'Social security (excl pensions)'},
#  '16013': {'category': '160',
#   'code': '16013',
#   'description': 'Social protection schemes in the form of cash or in-kind benefits, including pensions, against the risks linked to old age.',
#   'name': 'General pensions'},
#  '16014': {'category': '160',
#   'code': '16014',
#   'description': 'Pension schemes for government personnel.',
#   'name': 'Civil service pensions'},
#  '16015': {'category': '160',
#   'code': '16015',
#   'description': 'Social protection schemes in the form of cash or in-kind benefits to households with dependent children, including parental leave benefits.',
#   'name': 'Social services (incl youth development and women+ children)'},
#  '16020': {'category': '160',
#   'code': '16020',
#   'description': 'Employment policy and planning; labour law; labour unions; institution capacity building and advice; support programmes for unemployed; employment creation and income generation programmes; occupational safety and health; combating child labour.',
#   'name': 'Employment policy and administrative management'},
#  '16030': {'category': '160',
#   'code': '16030',
#   'description': 'Housing sector policy, planning and programmes; excluding low-cost housing and slum clearance (16040).',
#   'name': 'Housing policy and administrative management'},
#  '16040': {'category': '160',
#   'code': '16040',
#   'description': 'Including slum clearance.',
#   'name': 'Low-cost housing'},
#  '16050': {'category': '160',
#   'code': '16050',
#   'description': 'Basic social services are defined to include basic education, basic health, basic nutrition, population/reproductive health and basic drinking water supply and basic sanitation.',
#   'name': 'Multisector aid for basic social services'},
#  '16061': {'category': '160',
#   'code': '16061',
#   'description': 'Including libraries and museums.',
#   'name': 'Culture and recreation'},
#  '16062': {'category': '160',
#   'code': '16062',
#   'description': 'Both in national statistical offices and any other government ministries.',
#   'name': 'Statistical capacity building'},
#  '16063': {'category': '160',
#   'code': '16063',
#   'description': 'In-country and customs controls including training of the police; educational programmes and awareness campaigns to restrict narcotics traffic and in-country distribution.',
#   'name': 'Narcotics control'},
#  '16064': {'category': '160',
#   'code': '16064',
#   'description': 'Special programmes to address the consequences of HIV/AIDS, e.g. social, legal and economic assistance to people living with HIV/AIDS including food security and employment; support to vulnerable groups and children orphaned by HIV/AIDS; human rights of HIV/AIDS affected people.',
#   'name': 'Social mitigation of HIV/AIDS'},
#  '16065': {'category': '160',
#   'code': '16065',
#   'description': None,
#   'name': 'Recreation and sport'},
#  '16066': {'category': '160',
#   'code': '16066',
#   'description': None,
#   'name': 'Culture'},
#  '21010': {'category': '210',
#   'code': '21010',
#   'description': 'Transport sector policy, planning and programmes; aid to transport ministries; institution capacity building and advice; unspecified transport; activities that combine road, rail, water and/or air transport. Whenever possible, report transport of goods under the sector of the good being transported.',
#   'name': 'Transport policy and administrative management'},
#  '21011': {'category': '210',
#   'code': '21011',
#   'description': 'Administration of affairs and services concerning transport systems.',
#   'name': 'Transport policy, planning and administration'},
#  '21012': {'category': '210',
#   'code': '21012',
#   'description': 'Administration of affairs and services concerning public transport.',
#   'name': 'Public transport services'},
#  '21013': {'category': '210',
#   'code': '21013',
#   'description': 'Supervision and regulation of users, operations, construction and maintenance of transport systems (registration, licensing, inspection of equipment, operator skills and training; safety standards, franchises, tarriffs, levels of service, etc.).',
#   'name': 'Transport regulation'},
#  '21020': {'category': '210',
#   'code': '21020',
#   'description': 'Road infrastructure, road vehicles; passenger road transport, motor passenger cars.',
#   'name': 'Road transport'},
#  '21021': {'category': '210',
#   'code': '21021',
#   'description': 'Construction or operation of feeder road transport systems and facilities.',
#   'name': 'Feeder road construction'},
#  '21022': {'category': '210',
#   'code': '21022',
#   'description': 'Maintenance of feeder road transport systems and facilities.',
#   'name': 'Feeder road maintenance'},
#  '21023': {'category': '210',
#   'code': '21023',
#   'description': 'Construction or operation of national road transport systems and facilities.',
#   'name': 'National road construction'},
#  '21024': {'category': '210',
#   'code': '21024',
#   'description': 'Maintenance of national road transport systems and facilities.',
#   'name': 'National road maintenance'},
#  '21030': {'category': '210',
#   'code': '21030',
#   'description': 'Rail infrastructure, rail equipment, locomotives, other rolling stock; including light rail (tram) and underground systems.',
#   'name': 'Rail transport'},
#  '21040': {'category': '210',
#   'code': '21040',
#   'description': 'Harbours and docks, harbour guidance systems, ships and boats; river and other inland water transport, inland barges and vessels.',
#   'name': 'Water transport'},
#  '21050': {'category': '210',
#   'code': '21050',
#   'description': 'Airports, airport guidance systems, aeroplanes, aeroplane maintenance equipment.',
#   'name': 'Air transport'},
#  '21061': {'category': '210',
#   'code': '21061',
#   'description': 'Whether or not related to transportation. Whenever possible, report storage projects under the sector of the resource being stored.',
#   'name': 'Storage'},
#  '21081': {'category': '210',
#   'code': '21081',
#   'description': None,
#   'name': 'Education and training in transport and storage'},
#  '22010': {'category': '220',
#   'code': '22010',
#   'description': 'Communications sector policy, planning and programmes; institution capacity building and advice; including postal services development; unspecified communications activities.',
#   'name': 'Communications policy and administrative management'},
#  '22011': {'category': '220',
#   'code': '22011',
#   'description': None,
#   'name': 'Communications policy, planning and administration'},
#  '22012': {'category': '220',
#   'code': '22012',
#   'description': 'Development and operation of postal services.',
#   'name': 'Postal services'},
#  '22013': {'category': '220',
#   'code': '22013',
#   'description': 'Provision of information services.',
#   'name': 'Information services'},
#  '22020': {'category': '220',
#   'code': '22020',
#   'description': 'Telephone networks, telecommunication satellites, earth stations.',
#   'name': 'Telecommunications'},
#  '22030': {'category': '220',
#   'code': '22030',
#   'description': 'Radio and TV links, equipment; newspapers; printing and publishing.',
#   'name': 'Radio/television/print media'},
#  '22040': {'category': '220',
#   'code': '22040',
#   'description': 'Computer hardware and software; internet access; IT training. When sector cannot be specified.',
#   'name': 'Information and communication technology (ICT)'},
#  '23010': {'category': '230',
#   'code': '23010',
#   'description': 'Energy sector policy, planning and programmes; aid to energy ministries; institution capacity building and advice; unspecified energy activities including energy conservation.',
#   'name': 'Energy policy and administrative management'},
#  '23020': {'category': '230',
#   'code': '23020',
#   'description': 'Thermal power plants including when heat source cannot be determined; combined gas-coal power plants.',
#   'name': 'Power generation/non-renewable sources'},
#  '23030': {'category': '230',
#   'code': '23030',
#   'description': 'Including policy, planning, development programmes, surveys and incentives. Fuelwood/ charcoal production should be included under forestry (31261).',
#   'name': 'Power generation/renewable sources'},
#  '23040': {'category': '230',
#   'code': '23040',
#   'description': 'Distribution from power source to end user; transmission lines.',
#   'name': 'Electrical transmission/ distribution'},
#  '23050': {'category': '230',
#   'code': '23050',
#   'description': 'Delivery for use by ultimate consumer.',
#   'name': 'Gas distribution'},
#  '23061': {'category': '230',
#   'code': '23061',
#   'description': 'Including diesel power plants.',
#   'name': 'Oil-fired power plants'},
#  '23062': {'category': '230',
#   'code': '23062',
#   'description': None,
#   'name': 'Gas-fired power plants'},
#  '23063': {'category': '230',
#   'code': '23063',
#   'description': None,
#   'name': 'Coal-fired power plants'},
#  '23064': {'category': '230',
#   'code': '23064',
#   'description': 'Including nuclear safety.',
#   'name': 'Nuclear power plants'},
#  '23065': {'category': '230',
#   'code': '23065',
#   'description': 'Including power-generating river barges.',
#   'name': 'Hydro-electric power plants'},
#  '23066': {'category': '230',
#   'code': '23066',
#   'description': None,
#   'name': 'Geothermal energy'},
#  '23067': {'category': '230',
#   'code': '23067',
#   'description': 'Including photo-voltaic cells, solar thermal applications and solar heating.',
#   'name': 'Solar energy'},
#  '23068': {'category': '230',
#   'code': '23068',
#   'description': 'Wind energy for water lifting and electric power generation.',
#   'name': 'Wind power'},
#  '23069': {'category': '230',
#   'code': '23069',
#   'description': 'Including ocean thermal energy conversion, tidal and wave power.',
#   'name': 'Ocean power'},
#  '23070': {'category': '230',
#   'code': '23070',
#   'description': 'Densification technologies and use of biomass for direct power generation including biogas, gas obtained from sugar cane and other plant residues, anaerobic digesters.',
#   'name': 'Biomass'},
#  '23081': {'category': '230',
#   'code': '23081',
#   'description': 'Applies to all energy sub-sectors; all levels of training.',
#   'name': 'Energy education/training'},
#  '23082': {'category': '230',
#   'code': '23082',
#   'description': 'Including general inventories, surveys.',
#   'name': 'Energy research'},
#  '23110': {'category': '231',
#   'code': '23110',
#   'description': 'Energy sector policy, planning; aid to energy ministries; institution capacity building and advice; unspecified energy activities.',
#   'name': 'Energy policy and administrative management'},
#  '23111': {'category': '231',
#   'code': '23111',
#   'description': None,
#   'name': 'Energy sector policy, planning and administration'},
#  '23112': {'category': '231',
#   'code': '23112',
#   'description': 'Regulation of the energy sector, including wholesale and retail electricity provision.',
#   'name': 'Energy regulation'},
#  '23181': {'category': '231',
#   'code': '23181',
#   'description': 'All levels of training not included elsewhere.',
#   'name': 'Energy education/training'},
#  '23182': {'category': '231',
#   'code': '23182',
#   'description': 'Including general inventories, surveys.',
#   'name': 'Energy research'},
#  '23183': {'category': '231',
#   'code': '23183',
#   'description': 'All projects in support of energy demand reduction, e.g. building and industry upgrades, smart grids, metering and tariffs. Also includes efficient cook-stoves and biogas projects.',
#   'name': 'Energy conservation and demand-side efficiency'},
#  '23210': {'category': '232',
#   'code': '23210',
#   'description': 'Renewable energy generation programmes that cannot be attributed to one single technology (codes 23220 through 23280 below). Fuelwood/charcoal production should be included under forestry 31261.',
#   'name': 'Energy generation, renewable sources – multiple technologies'},
#  '23220': {'category': '232',
#   'code': '23220',
#   'description': 'Including energy generating river barges.',
#   'name': 'Hydro-electric power plants'},
#  '23230': {'category': '232',
#   'code': '23230',
#   'description': 'Including photo-voltaic cells, solar thermal applications and solar heating.',
#   'name': 'Solar energy'},
#  '23240': {'category': '232',
#   'code': '23240',
#   'description': 'Wind energy for water lifting and electric power generation.',
#   'name': 'Wind energy'},
#  '23250': {'category': '232',
#   'code': '23250',
#   'description': 'Including ocean thermal energy conversion, tidal and wave power.',
#   'name': 'Marine energy'},
#  '23260': {'category': '232',
#   'code': '23260',
#   'description': 'Use of geothermal energy for generating electric power or directly as heat for agriculture, etc.',
#   'name': 'Geothermal energy'},
#  '23270': {'category': '232',
#   'code': '23270',
#   'description': 'Use of solids and liquids produced from biomass for direct power generation. Also includes biogases from anaerobic fermentation (e.g. landfill gas, sewage sludge gas, fermentation of energy crops and manure) and thermal processes (also known as syngas); waste-fired power plants making use of biodegradable municipal waste (household waste and waste from companies and public services that resembles household waste, collected at installations specifically designed for their disposal with recovery of combustible liquids, gases or heat). See code 23360 for non- renewable waste-fired power plants.',
#   'name': 'Biofuel-fired power plants'},
#  '23310': {'category': '233',
#   'code': '23310',
#   'description': 'Thermal power plants including when energy source cannot be determined; combined gas-coal power plants.',
#   'name': 'Energy generation, non-renewable sources – unspecified'},
#  '23320': {'category': '233',
#   'code': '23320',
#   'description': 'Thermal electric power plants that use coal as the energy source.',
#   'name': 'Coal-fired electric power plants'},
#  '23330': {'category': '233',
#   'code': '23330',
#   'description': 'Thermal electric power plants that use fuel oil or diesel fuel as the energy source.',
#   'name': 'Oil-fired electric power plants'},
# ...
#   'name': 'Engineering'},
#  '32172': {'category': '321',
#   'code': '32172',
#   'description': 'Shipbuilding, fishing boats building; railroad equipment; motor vehicles and motor passenger cars; aircraft; navigation/guidance systems.',
#   'name': 'Transport equipment industry'},
#  '32182': {'category': '321',
#   'code': '32182',
#   'description': 'Including industrial standards; quality management; metrology; testing; accreditation; certification.',
#   'name': 'Technological research and development'},
#  '32210': {'category': '322',
#   'code': '32210',
#   'description': 'Mineral and mining sector policy, planning and programmes; mining legislation, mining cadastre, mineral resources inventory, information systems, institution capacity building and advice; unspecified mineral resources exploitation.',
#   'name': 'Mineral/mining policy and administrative management'},
#  '32220': {'category': '322',
#   'code': '32220',
#   'description': 'Geology, geophysics, geochemistry; excluding hydrogeology (14010) and environmental geology (41010), mineral extraction and processing, infrastructure, technology, economics, safety and environment management.',
#   'name': 'Mineral prospection and exploration'},
#  '32261': {'category': '322',
#   'code': '32261',
#   'description': 'Including lignite and peat.',
#   'name': 'Coal'},
#  '32262': {'category': '322',
#   'code': '32262',
#   'description': 'Petroleum, natural gas, condensates, liquefied petroleum gas (LPG), liquefied natural gas (LNG); including drilling and production, and oil and gas pipelines.',
#   'name': 'Oil and gas'},
#  '32263': {'category': '322',
#   'code': '32263',
#   'description': 'Iron and ferro-alloy metals.',
#   'name': 'Ferrous metals'},
#  '32264': {'category': '322',
#   'code': '32264',
#   'description': 'Aluminium, copper, lead, nickel, tin, zinc.',
#   'name': 'Nonferrous metals'},
#  '32265': {'category': '322',
#   'code': '32265',
#   'description': 'Gold, silver, platinum, diamonds, gemstones.',
#   'name': 'Precious metals/materials'},
#  '32266': {'category': '322',
#   'code': '32266',
#   'description': 'Baryte, limestone, feldspar, kaolin, sand, gypsym, gravel, ornamental stones.',
#   'name': 'Industrial minerals'},
#  '32267': {'category': '322',
#   'code': '32267',
#   'description': 'Phosphates, potash.',
#   'name': 'Fertilizer minerals'},
#  '32268': {'category': '322',
#   'code': '32268',
#   'description': 'Polymetallic nodules, phosphorites, marine placer deposits.',
#   'name': 'Offshore minerals'},
#  '32310': {'category': '323',
#   'code': '32310',
#   'description': 'Construction sector policy and planning; excluding construction activities within specific sectors (e.g., hospital or school construction).',
#   'name': 'Construction policy and administrative management'},
#  '33110': {'category': '331',
#   'code': '33110',
#   'description': 'Trade policy and planning; support to ministries and departments responsible for trade policy; trade-related legislation and regulatory reforms; policy analysis and implementation of multilateral trade agreements e.g. technical barriers to trade and sanitary and phytosanitary measures (TBT/SPS) except at regional level (see 33130); mainstreaming trade in national development strategies (e.g. poverty reduction strategy papers); wholesale/retail trade; unspecified trade and trade promotion activities.',
#   'name': 'Trade policy and administrative Management'},
#  '33120': {'category': '331',
#   'code': '33120',
#   'description': 'Simplification and harmonisation of international import and export procedures (e.g. customs valuation, licensing procedures, transport formalities, payments, insurance); support to customs departments and other border agencies, including in particular implementation of the provisions of the WTO Trade Facilitation Agreement; tariff reforms.',
#   'name': 'Trade facilitation'},
#  '33130': {'category': '331',
#   'code': '33130',
#   'description': 'Support to regional trade arrangements [e.g. Southern African Development Community (SADC), Association of Southeast Asian Nations (ASEAN), Free Trade Area of the Americas (FTAA), African Caribbean Pacific/European Union (ACP/EU)], including work on technical barriers to trade and sanitary and phytosanitary measures (TBT/SPS) at regional level; elaboration of rules of origin and introduction of special and differential treatment in RTAs.',
#   'name': 'Regional trade agreements (RTAs)'},
#  '33140': {'category': '331',
#   'code': '33140',
#   'description': 'Support developing countries’ effective participation in multilateral trade negotiations, including training of negotiators, assessing impacts of negotiations; accession to the World Trade Organisation (WTO) and other multilateral trade-related organisations.',
#   'name': 'Multilateral trade negotiations'},
#  '33150': {'category': '331',
#   'code': '33150',
#   'description': 'Contributions to the government budget to assist the implementation of recipients’ own trade reforms and adjustments to trade policy measures by other countries; assistance to manage shortfalls in the balance of payments due to changes in the world trading environment.',
#   'name': 'Trade-related adjustment'},
#  '33181': {'category': '331',
#   'code': '33181',
#   'description': 'Human resources development in trade not included under any of the above codes. Includes university programmes in trade.',
#   'name': 'Trade education/training'},
#  '33210': {'category': '332',
#   'code': '33210',
#   'description': None,
#   'name': 'Tourism policy and administrative management'},
#  '41010': {'category': '410',
#   'code': '41010',
#   'description': 'Environmental policy, laws, regulations and economic instruments; administrational institutions and practices; environmental and land use planning and decision-making procedures; seminars, meetings; miscellaneous conservation and protection measures not specified below.',
#   'name': 'Environmental policy and administrative management'},
#  '41020': {'category': '410',
#   'code': '41020',
#   'description': 'Air pollution control, ozone layer preservation; marine pollution control.',
#   'name': 'Biosphere protection'},
#  '41030': {'category': '410',
#   'code': '41030',
#   'description': 'Including natural reserves and actions in the surrounding areas; other measures to protect endangered or vulnerable species and their habitats (e.g. wetlands preservation).',
#   'name': 'Bio-diversity'},
#  '41040': {'category': '410',
#   'code': '41040',
#   'description': 'Applies to unique cultural landscape; including sites/objects of historical, archeological, aesthetic, scientific or educational value.',
#   'name': 'Site preservation'},
#  '41050': {'category': '410',
#   'code': '41050',
#   'description': 'Floods from rivers or the sea; including sea water intrusion control and sea level rise related activities.',
#   'name': 'Flood prevention/control'},
#  '41081': {'category': '410',
#   'code': '41081',
#   'description': None,
#   'name': 'Environmental education/ training'},
#  '41082': {'category': '410',
#   'code': '41082',
#   'description': 'Including establishment of databases, inventories/accounts of physical and natural resources; environmental profiles and impact studies if not sector specific.',
#   'name': 'Environmental research'},
#  '43010': {'category': '430',
#   'code': '43010',
#   'description': None,
#   'name': 'Multisector aid'},
#  '43030': {'category': '430',
#   'code': '43030',
#   'description': 'Integrated urban development projects; local development and urban management; urban infrastructure and services; municipal finances; urban environmental management; urban development and planning; urban renewal and urban housing; land information systems.',
#   'name': 'Urban development and management'},
#  '43031': {'category': '430',
#   'code': '43031',
#   'description': 'Urban development and planning; urban management, land information systems.',
#   'name': 'Urban land policy and management'},
#  '43032': {'category': '430',
#   'code': '43032',
#   'description': 'Integrated urban development projects; local development; urban infrastructure and services; municipal finances; urban environment systems; urban renewal and urban housing.',
#   'name': 'Urban development'},
#  '43040': {'category': '430',
#   'code': '43040',
#   'description': 'Integrated rural development projects; e.g. regional development planning; promotion of decentralised and multi-sectoral competence for planning, co-ordination and management; implementation of regional development and measures (including natural reserve management); land management; land use planning; land settlement and resettlement activities [excluding resettlement of refugees and internally displaced persons (72010)]; functional integration of rural and urban areas; geographical information systems.',
#   'name': 'Rural development'},
#  '43041': {'category': '430',
#   'code': '43041',
#   'description': 'Regional development planning; promotion of decentralised and multi-sectoral competence for planning, co-ordination and management; land management; land use planning; geographical information systems.',
#   'name': 'Rural land policy and management'},
#  '43042': {'category': '430',
#   'code': '43042',
#   'description': 'Integrated rural development projects; implementation of regional development and measures (including natural reserve management); land settlement and resettlement activities [excluding resettlement of refugees and internally displaced persons (72010)]; functional integration of rural and urban areas.',
#   'name': 'Rural development'},
#  '43050': {'category': '430',
#   'code': '43050',
#   'description': 'Projects to reduce illicit drug cultivation through, for example, non-agricultural income opportunities, social and physical infrastructure (see code 31165 for agricultural alternative development).',
#   'name': 'Non-agricultural alternative development'},
#  '43081': {'category': '430',
#   'code': '43081',
#   'description': 'Including scholarships.',
#   'name': 'Multisector education/training'},
#  '43082': {'category': '430',
#   'code': '43082',
#   'description': 'When sector cannot be identified.',
#   'name': 'Research/scientific institutions'},
#  '51010': {'category': '510',
#   'code': '51010',
#   'description': 'Unearmarked contributions to the government budget; support for the implementation of macroeconomic reforms (structural adjustment programmes, poverty reduction strategies); general programme assistance (when not allocable by sector).',
#   'name': 'General budget support-related aid'},
#  '52010': {'category': '520',
#   'code': '52010',
#   'description': 'Supply of edible human food under national or international programmes including transport costs; cash payments made for food supplies; project food aid and food aid for market sales when benefiting sector not specified; excluding emergency food aid. Report as multilateral: i) food aid by the EU financed out of its budget and allocated pro rata to EU member countries; and ii) core contributions to the World Food Programme.',
#   'name': 'Food aid/Food security programmes'},
#  '53030': {'category': '530',
#   'code': '53030',
#   'description': 'Capital goods and services; lines of credit.',
#   'name': 'Import support (capital goods)'},
#  '53040': {'category': '530',
#   'code': '53040',
#   'description': 'Commodities, general goods and services, oil imports.',
#   'name': 'Import support (commodities)'},
#  '60010': {'category': '600',
#   'code': '60010',
#   'description': 'Actions falling outside the code headings below.',
#   'name': 'Action relating to debt'},
#  '60020': {'category': '600',
#   'code': '60020',
#   'description': None,
#   'name': 'Debt forgiveness'},
#  '60030': {'category': '600',
#   'code': '60030',
#   'description': 'Grants or credits to cover debt owed to multilateral financial institutions; including contributions to Heavily Indebted Poor Countries (HIPC) Trust Fund.',
#   'name': 'Relief of multilateral debt'},
#  '60040': {'category': '600',
#   'code': '60040',
#   'description': None,
#   'name': 'Rescheduling and refinancing'},
#  '60061': {'category': '600',
#   'code': '60061',
#   'description': 'Allocation of debt claims to use for development (e.g., debt for education, debt for environment).',
#   'name': 'Debt for development swap'},
#  '60062': {'category': '600',
#   'code': '60062',
#   'description': 'Where the debt swap benefits an external agent i.e. is not specifically for development purposes.',
#   'name': 'Other debt swap'},
#  '60063': {'category': '600',
#   'code': '60063',
#   'description': 'Purchase of debt for the purpose of cancellation.',
#   'name': 'Debt buy-back'},
#  '72010': {'category': '720',
#   'code': '72010',
#   'description': 'Shelter, water, sanitation and health services, supply of medicines and other non-food relief items for the benefit of affected people and to facilitate the return to normal lives and livelihoods; assistance to refugees and internally displaced people in developing countries other than for food (72040) or protection (72050).',
#   'name': 'Material relief assistance and services'},
#  '72040': {'category': '720',
#   'code': '72040',
#   'description': 'Food aid normally for general free distribution or special supplementary feeding programmes; short-term relief to targeted population groups affected by emergency situations. Excludes non-emergency food security assistance programmes/food aid (52010).',
#   'name': 'Emergency food aid'},
#  '72050': {'category': '720',
#   'code': '72050',
#   'description': 'Measures to co-ordinate delivery of humanitarian aid, including logistics and communications systems; measures to promote and protect the safety, well- being, dignity and integrity of civilians and those no longer taking part in hostilities. (Activities designed to protect the security of persons or property through the use or display of force are not reportable as ODA.)',
#   'name': 'Relief co-ordination; protection and support services'},
#  '73010': {'category': '730',
#   'code': '73010',
#   'description': 'Short-term reconstruction work after emergency or conflict limited to restoring pre-existing infrastructure (e.g. repair or construction of roads, bridges and ports, restoration of essential facilities, such as water and sanitation, shelter, health care services); social and economic rehabilitation in the aftermath of emergencies to facilitate transition and enable populations to return to their previous livelihood or develop a new livelihood in the wake of an emergency situation (e.g. trauma counselling and treatment, employment programmes).',
#   'name': 'Reconstruction relief and rehabilitation'},
#  '74010': {'category': '740',
#   'code': '74010',
#   'description': 'Disaster risk reduction activities (e.g. developing knowledge, natural risks cartography, legal norms for construction); early warning systems; emergency contingency stocks and contingency planning including preparations for forced displacement.',
#   'name': 'Disaster prevention and preparedness'},
#  '91010': {'category': '910',
#   'code': '91010',
#   'description': None,
#   'name': 'Administrative costs (non-sector allocable)'},
#  '92010': {'category': '920',
#   'code': '92010',
#   'description': 'In the donor country.',
#   'name': 'Support to national NGOs'},
#  '92020': {'category': '920',
#   'code': '92020',
#   'description': None,
#   'name': 'Support to international NGOs'},
#  '92030': {'category': '920',
#   'code': '92030',
#   'description': 'In the recipient country or region.',
#   'name': 'Support to local and regional NGOs'},
#  '93010': {'category': '930',
#   'code': '93010',
#   'description': None,
#   'name': 'Refugees in donor countries (non-sector allocable)'},
#  '99810': {'category': '998',
#   'code': '99810',
#   'description': 'Contributions to general development of the recipient should be included under programme assistance (51010).',
#   'name': 'Sectors not specified'},
#  '99820': {'category': '998',
#   'code': '99820',
#   'description': 'Spending in donor country for heightened awareness/interest in development co-operation (brochures, lectures, special research projects, etc.).',
#   'name': 'Promotion of development awareness (non-sector allocable)'}}

# %%
sector_categories_url = 'http://iatistandard.org/202/codelists/downloads/clv3/json/en/SectorCategory.json'
sector_categories_json = requests.get(sector_categories_url).json()['data']
sector_categories = {
    item['code']: item for item in sector_categories_json
}

# %%
sector_categories
# Out:
# {'111': {'code': '111',
#   'description': 'Education sector policy, planning and programmes; aid to education ministries, administration and management systems; institution capacity building and advice; school management and governance; curriculum and materials development; unspecified education activities.',
#   'name': 'Education, level unspecified'},
#  '112': {'code': '112',
#   'description': 'Formal and non-formal primary education for children; all elementary and first cycle systematic instruction; provision of learning materials.',
#   'name': 'Basic education'},
#  '113': {'code': '113',
#   'description': 'Second cycle systematic instruction at both junior and senior levels.',
#   'name': 'Secondary education'},
#  '114': {'code': '114',
#   'description': 'Degree and diploma programmes at universities, colleges and polytechnics; scholarships.',
#   'name': 'Post-secondary education'},
#  '121': {'code': '121',
#   'description': 'Health sector policy, planning and programmes; aid to health ministries, public health administration; institution capacity building and advice; medical insurance programmes; unspecified health activities.',
#   'name': 'Health, general'},
#  '122': {'code': '122',
#   'description': 'Basic and primary health care programmes; paramedical and nursing care programmes; supply of drugs, medicines and vaccines related to basic health care.',
#   'name': 'Basic health'},
#  '130': {'code': '130',
#   'description': 'Population/development policies; census work, vital registration; migration data; demographic research/analysis; reproductive health research; unspecified population activities.',
#   'name': 'POPULATION POLICIES/ PROGRAMMES AND REPRODUCTIVE HEALTH'},
#  '140': {'code': '140',
#   'description': 'Water sector policy and governance, including legislation, regulation, planning and management as well as transboundary management of water; institutional capacity development; activities supporting the Integrated Water Resource Management approach (IWRM: see box below).',
#   'name': 'WATER AND SANITATION'},
#  '151': {'code': '151',
#   'description': 'Institution-building assistance to strengthen core public sector management systems and capacities. This includes macro-economic and other policy management, co-ordination, planning and reform; human resource management; organisational development; civil service reform; e-government; development planning, monitoring and evaluation; support to ministries involved in aid co-ordination; other ministries and government departments when sector cannot be specified. (Use specific sector codes for development of systems and capacities in sector ministries.)',
#   'name': 'Government and civil society, general'},
#  '152': {'code': '152',
#   'description': 'Technical co-operation provided to parliament, government ministries, law enforcement agencies and the judiciary to assist review and reform of the security system to improve democratic governance and civilian control; technical co-operation provided to government to improve civilian oversight and democratic control of budgeting, management, accountability and auditing of security expenditure, including military budgets, as part of a public expenditure management programme; assistance to civil society to enhance its competence and capacity to scrutinise the security system so that it is managed in accordance with democratic norms and principles of accountability, transparency and good governance. [Other than in the context of an international peacekeeping operation (15230).]',
#   'name': 'Conflict prevention and resolution, peace and security'},
#  '160': {'code': '160',
#   'description': 'Social legislation and administration; institution capacity building and advice; social security and other social schemes; special programmes for the elderly, orphans, the disabled, street children; social dimensions of structural adjustment; unspecified social infrastructure and services, including consumer protection.',
#   'name': 'OTHER SOCIAL INFRASTRUCTURE AND SERVICES'},
#  '210': {'code': '210',
#   'description': 'Transport sector policy, planning and programmes; aid to transport ministries; institution capacity building and advice; unspecified transport; activities that combine road, rail, water and/or air transport. Whenever possible, report transport of goods under the sector of the good being transported.',
#   'name': 'TRANSPORT AND STORAGE'},
#  '220': {'code': '220',
#   'description': 'Communications sector policy, planning and programmes; institution capacity building and advice; including postal services development; unspecified communications activities.',
#   'name': 'COMMUNICATIONS'},
#  '230': {'code': '230',
#   'description': 'Energy sector policy, planning and programmes; aid to energy ministries; institution capacity building and advice; unspecified energy activities including energy conservation.',
#   'name': 'ENERGY GENERATION AND SUPPLY'},
#  '231': {'code': '231',
#   'description': 'Energy sector policy, planning; aid to energy ministries; institution capacity building and advice; unspecified energy activities.',
#   'name': 'Energy generation, distribution and efficiency – general'},
#  '232': {'code': '232',
#   'description': 'Renewable energy generation programmes that cannot be attributed to one single technology (codes 23220 through 23280 below). Fuelwood/charcoal production should be included under forestry 31261.',
#   'name': 'Energy generation, renewable sources'},
#  '233': {'code': '233',
#   'description': 'Thermal power plants including when energy source cannot be determined; combined gas-coal power plants.',
#   'name': 'Energy generation, non-renewable sources'},
#  '234': {'code': '234',
#   'description': 'Electric power plants that make use of both non-renewable and renewable energy sources.',
#   'name': 'Hybrid energy electric power plants'},
#  '235': {'code': '235',
#   'description': 'Including nuclear safety.',
#   'name': 'Nuclear energy electric power plants'},
#  '236': {'code': '236',
#   'description': 'Power plants which are designed to produce heat only.',
#   'name': 'Heating, cooling and energy distribution'},
#  '240': {'code': '240',
#   'description': 'Finance sector policy, planning and programmes; institution capacity building and advice; financial markets and systems.',
#   'name': 'BANKING AND FINANCIAL SERVICES'},
#  '250': {'code': '250',
#   'description': 'Support to trade and business associations, chambers of commerce; legal and regulatory reform aimed at improving business and investment climate; private sector institution capacity building and advice; trade information; public-private sector networking including trade fairs; e-commerce. Where sector cannot be specified: general support to private sector enterprises (in particular, use code 32130 for enterprises in the industrial sector).',
#   'name': 'BUSINESS AND OTHER SERVICES'},
#  '311': {'code': '311',
#   'description': 'Agricultural sector policy, planning and programmes; aid to agricultural ministries; institution capacity building and advice; unspecified agriculture.',
#   'name': 'AGRICULTURE'},
#  '312': {'code': '312',
#   'description': 'Forestry sector policy, planning and programmes; institution capacity building and advice; forest surveys; unspecified forestry and agro-forestry activities.',
#   'name': 'FORESTRY'},
#  '313': {'code': '313',
#   'description': 'Fishing sector policy, planning and programmes; institution capacity building and advice; ocean and coastal fishing; marine and freshwater fish surveys and prospecting; fishing boats/equipment; unspecified fishing activities.',
#   'name': 'FISHING'},
#  '321': {'code': '321',
#   'description': 'Industrial sector policy, planning and programmes; institution capacity building and advice; unspecified industrial activities; manufacturing of goods not specified below.',
#   'name': 'INDUSTRY'},
#  '322': {'code': '322',
#   'description': 'Mineral and mining sector policy, planning and programmes; mining legislation, mining cadastre, mineral resources inventory, information systems, institution capacity building and advice; unspecified mineral resources exploitation.',
#   'name': 'MINERAL RESOURCES AND MINING'},
#  '323': {'code': '323',
#   'description': 'Construction sector policy and planning; excluding construction activities within specific sectors (e.g., hospital or school construction).',
#   'name': 'CONSTRUCTION'},
#  '331': {'code': '331',
#   'description': 'Trade policy and planning; support to ministries and departments responsible for trade policy; trade-related legislation and regulatory reforms; policy analysis and implementation of multilateral trade agreements e.g. technical barriers to trade and sanitary and phytosanitary measures (TBT/SPS) except at regional level (see 33130); mainstreaming trade in national development strategies (e.g. poverty reduction strategy papers); wholesale/retail trade; unspecified trade and trade promotion activities.',
#   'name': 'TRADE POLICY AND REGULATIONS AND TRADE- RELATED ADJUSTMENT'},
#  '332': {'code': '332', 'description': None, 'name': 'TOURISM'},
#  '410': {'code': '410',
#   'description': 'Environmental policy, laws, regulations and economic instruments; administrational institutions and practices; environmental and land use planning and decision-making procedures; seminars, meetings; miscellaneous conservation and protection measures not specified below.',
#   'name': 'General environmental protection'},
#  '430': {'code': '430', 'description': None, 'name': 'Other multisector'},
#  '510': {'code': '510',
#   'description': 'Unearmarked contributions to the government budget; support for the implementation of macroeconomic reforms (structural adjustment programmes, poverty reduction strategies); general programme assistance (when not allocable by sector).',
#   'name': 'General budget support'},
#  '520': {'code': '520',
#   'description': 'Supply of edible human food under national or international programmes including transport costs; cash payments made for food supplies; project food aid and food aid for market sales when benefiting sector not specified; excluding emergency food aid. Report as multilateral: i) food aid by the EU financed out of its budget and allocated pro rata to EU member countries; and ii) core contributions to the World Food Programme.',
#   'name': 'Developmental food aid/Food security assistance'},
#  '530': {'code': '530',
#   'description': 'Capital goods and services; lines of credit.',
#   'name': 'Other commodity assistance'},
#  '600': {'code': '600',
#   'description': 'Actions falling outside the code headings below.',
#   'name': 'Debt relief'},
#  '720': {'code': '720',
#   'description': 'Shelter, water, sanitation and health services, supply of medicines and other non-food relief items for the benefit of affected people and to facilitate the return to normal lives and livelihoods; assistance to refugees and internally displaced people in developing countries other than for food (72040) or protection (72050).',
#   'name': 'Emergency Response'},
#  '730': {'code': '730',
#   'description': 'Short-term reconstruction work after emergency or conflict limited to restoring pre-existing infrastructure (e.g. repair or construction of roads, bridges and ports, restoration of essential facilities, such as water and sanitation, shelter, health care services); social and economic rehabilitation in the aftermath of emergencies to facilitate transition and enable populations to return to their previous livelihood or develop a new livelihood in the wake of an emergency situation (e.g. trauma counselling and treatment, employment programmes).',
#   'name': 'Reconstruction relief and rehabilitation'},
#  '740': {'code': '740',
#   'description': 'Disaster risk reduction activities (e.g. developing knowledge, natural risks cartography, legal norms for construction); early warning systems; emergency contingency stocks and contingency planning including preparations for forced displacement.',
#   'name': 'Disaster prevention and preparedness'},
#  '910': {'code': '910',
#   'description': None,
#   'name': 'ADMINISTRATIVE COSTS OF DONORS'},
#  '920': {'code': '920',
#   'description': 'In the donor country.',
#   'name': 'SUPPORT TO NON- GOVERNMENTAL ORGANISATIONS (NGOs)'},
#  '930': {'code': '930',
#   'description': None,
#   'name': 'REFUGEES IN DONOR COUNTRIES'},
#  '998': {'code': '998',
#   'description': 'Contributions to general development of the recipient should be included under programme assistance (51010).',
#   'name': 'UNALLOCATED/ UNSPECIFIED'}}

# %%
policy_marker_url = 'http://iatistandard.org/202/codelists/downloads/clv3/json/en/PolicyMarker.json'
policy_markers_json = requests.get(policy_marker_url).json()['data']
policy_markers = {
    item['code']: item for item in policy_markers_json
}

# %%
policy_markers
# Out:
# {'1': {'code': '1', 'name': 'Gender Equality'},
#  '2': {'code': '2', 'name': 'Aid to Environment'},
#  '3': {'code': '3', 'name': 'Participatory Development/Good Governance'},
#  '4': {'code': '4', 'name': 'Trade Development'},
#  '5': {'code': '5',
#   'name': 'Aid Targeting the Objectives of the Convention on Biological Diversity'},
#  '6': {'code': '6',
#   'name': 'Aid Targeting the Objectives of the Framework Convention on Climate Change - Mitigation'},
#  '7': {'code': '7',
#   'name': 'Aid Targeting the Objectives of the Framework Convention on Climate Change - Adaptation'},
#  '8': {'code': '8',
#   'name': 'Aid Targeting the Objectives of the Convention to Combat Desertification'},
#  '9': {'code': '9',
#   'name': 'Reproductive, Maternal, Newborn and Child Health (RMNCH)'}}

# %% [markdown]
# # Create Term Vectors

# %% [markdown]
# For the names and descriptions, we'll tokenize them and store the words that are used in the names/descriptions inside of a dictionary of sets. This will let us perform cosine similarity of search terms against the terms that are actually used in sector codes and policy markers.

# %%
def add_attribute(item, item_attribute, search_item, search_attribute):
    if item_attribute not in item:
        search_item[search_attribute + '_raw'] = ''
        search_item[search_attribute] = set()
        return

    raw_value = item[item_attribute]

    if raw_value is None:
        search_item[search_attribute + '_raw'] = ''
        search_item[search_attribute] = set()
        return

    raw_value = raw_value.lower().strip()
    search_item[search_attribute + '_raw'] = raw_value

    if len(raw_value) == 0:
        search_item[search_attribute] = set()
        return

    tokenized_value = set([
        item for item in re.split('[^a-z]+', raw_value.strip().lower())
            if len(item) > 0
    ])

    search_item[search_attribute] = tokenized_value

# %%
searchable_sectors = {}

for code, sector in sectors.items():
    category_id = sector['category']

    sector_data = {}

    add_attribute(sector, 'name', sector_data, 'sector_name')
    add_attribute(sector, 'description', sector_data, 'sector_description')

    if category_id in sector_categories:
        category = sector_categories[category_id]
        add_attribute(category, 'name', sector_data, 'category_name')
        add_attribute(category, 'description', sector_data, 'category_description')
    else:
        print('Missing category:', category_id)

    searchable_sectors[code] = sector_data

# %%
searchable_sectors
# Out:
# {'11110': {'category_description': {'activities',
#    'administration',
#    'advice',
#    'aid',
#    'and',
#    'building',
#    'capacity',
#    'curriculum',
#    'development',
#    'education',
#    'governance',
#    'institution',
#    'management',
#    'materials',
#    'ministries',
#    'planning',
#    'policy',
#    'programmes',
#    'school',
#    'sector',
#    'systems',
#    'to',
#    'unspecified'},
#   'category_description_raw': 'education sector policy, planning and programmes; aid to education ministries, administration and management systems; institution capacity building and advice; school management and governance; curriculum and materials development; unspecified education activities.',
#   'category_name': {'education', 'level', 'unspecified'},
#   'category_name_raw': 'education, level unspecified',
#   'sector_description': {'activities',
#    'administration',
#    'advice',
#    'aid',
#    'and',
#    'building',
#    'capacity',
#    'curriculum',
#    'development',
#    'education',
#    'governance',
#    'institution',
#    'management',
#    'materials',
#    'ministries',
#    'planning',
#    'policy',
#    'programmes',
#    'school',
#    'sector',
#    'systems',
#    'to',
#    'unspecified'},
#   'sector_description_raw': 'education sector policy, planning and programmes; aid to education ministries, administration and management systems; institution capacity building and advice; school management and governance; curriculum and materials development; unspecified education activities.',
#   'sector_name': {'administrative',
#    'and',
#    'education',
#    'management',
#    'policy'},
#   'sector_name_raw': 'education policy and administrative management'},
#  '11120': {'category_description': {'activities',
#    'administration',
#    'advice',
#    'aid',
#    'and',
#    'building',
#    'capacity',
#    'curriculum',
#    'development',
#    'education',
#    'governance',
#    'institution',
#    'management',
#    'materials',
#    'ministries',
#    'planning',
#    'policy',
#    'programmes',
#    'school',
#    'sector',
#    'systems',
#    'to',
#    'unspecified'},
#   'category_description_raw': 'education sector policy, planning and programmes; aid to education ministries, administration and management systems; institution capacity building and advice; school management and governance; curriculum and materials development; unspecified education activities.',
#   'category_name': {'education', 'level', 'unspecified'},
#   'category_name_raw': 'education, level unspecified',
#   'sector_description': {'boarding',
#    'buildings',
#    'colloquia',
#    'education',
#    'educational',
#    'equipment',
#    'etc',
#    'facilities',
#    'housing',
#    'language',
#    'lectures',
#    'materials',
#    'seminars',
#    'services',
#    'staff',
#    'subsidiary',
#    'to',
#    'training'},
#   'sector_description_raw': 'educational buildings, equipment, materials; subsidiary services to education (boarding facilities, staff housing); language training; colloquia, seminars, lectures, etc.',
#   'sector_name': {'and', 'education', 'facilities', 'training'},
#   'sector_name_raw': 'education facilities and training'},
#  '11130': {'category_description': {'activities',
#    'administration',
#    'advice',
#    'aid',
#    'and',
#    'building',
#    'capacity',
#    'curriculum',
#    'development',
#    'education',
#    'governance',
#    'institution',
#    'management',
#    'materials',
#    'ministries',
#    'planning',
#    'policy',
#    'programmes',
#    'school',
#    'sector',
#    'systems',
#    'to',
#    'unspecified'},
#   'category_description_raw': 'education sector policy, planning and programmes; aid to education ministries, administration and management systems; institution capacity building and advice; school management and governance; curriculum and materials development; unspecified education activities.',
#   'category_name': {'education', 'level', 'unspecified'},
#   'category_name_raw': 'education, level unspecified',
#   'sector_description': {'and',
#    'development',
#    'education',
#    'in',
#    'is',
#    'level',
#    'materials',
#    'of',
#    'pre',
#    'service',
#    'teacher',
#    'the',
#    'training',
#    'unspecified',
#    'where'},
#   'sector_description_raw': 'teacher education (where the level of education is unspecified); in-service and pre-service training; materials development.',
#   'sector_name': {'teacher', 'training'},
#   'sector_name_raw': 'teacher training'},
#  '11182': {'category_description': {'activities',
#    'administration',
#    'advice',
#    'aid',
#    'and',
#    'building',
#    'capacity',
#    'curriculum',
#    'development',
#    'education',
#    'governance',
#    'institution',
#    'management',
#    'materials',
#    'ministries',
#    'planning',
#    'policy',
#    'programmes',
#    'school',
#    'sector',
#    'systems',
#    'to',
#    'unspecified'},
#   'category_description_raw': 'education sector policy, planning and programmes; aid to education ministries, administration and management systems; institution capacity building and advice; school management and governance; curriculum and materials development; unspecified education activities.',
#   'category_name': {'education', 'level', 'unspecified'},
#   'category_name_raw': 'education, level unspecified',
#   'sector_description': {'and',
#    'education',
#    'effectiveness',
#    'evaluation',
#    'monitoring',
#    'on',
#    'quality',
#    'relevance',
#    'research',
#    'studies',
#    'systematic'},
#   'sector_description_raw': 'research and studies on education effectiveness, relevance and quality; systematic evaluation and monitoring.',
#   'sector_name': {'educational', 'research'},
#   'sector_name_raw': 'educational research'},
#  '11220': {'category_description': {'all',
#    'and',
#    'children',
#    'cycle',
#    'education',
#    'elementary',
#    'first',
#    'for',
#    'formal',
#    'instruction',
#    'learning',
#    'materials',
#    'non',
#    'of',
#    'primary',
#    'provision',
#    'systematic'},
#   'category_description_raw': 'formal and non-formal primary education for children; all elementary and first cycle systematic instruction; provision of learning materials.',
#   'category_name': {'basic', 'education'},
#   'category_name_raw': 'basic education',
#   'sector_description': {'all',
#    'and',
#    'children',
#    'cycle',
#    'education',
#    'elementary',
#    'first',
#    'for',
#    'formal',
#    'instruction',
#    'learning',
#    'materials',
#    'non',
#    'of',
#    'primary',
#    'provision',
#    'systematic'},
#   'sector_description_raw': 'formal and non-formal primary education for children; all elementary and first cycle systematic instruction; provision of learning materials.',
#   'sector_name': {'education', 'primary'},
#   'sector_name_raw': 'primary education'},
#  '11230': {'category_description': {'all',
#    'and',
#    'children',
#    'cycle',
#    'education',
#    'elementary',
#    'first',
#    'for',
#    'formal',
#    'instruction',
#    'learning',
#    'materials',
#    'non',
#    'of',
#    'primary',
#    'provision',
#    'systematic'},
#   'category_description_raw': 'formal and non-formal primary education for children; all elementary and first cycle systematic instruction; provision of learning materials.',
#   'category_name': {'basic', 'education'},
#   'category_name_raw': 'basic education',
#   'sector_description': {'adults',
#    'and',
#    'basic',
#    'education',
#    'for',
#    'formal',
#    'life',
#    'literacy',
#    'non',
#    'numeracy',
#    'people',
#    'skills',
#    'training',
#    'young'},
#   'sector_description_raw': 'formal and non-formal education for basic life skills for young people and adults (adults education); literacy and numeracy training.',
#   'sector_name': {'adults', 'and', 'basic', 'for', 'life', 'skills', 'youth'},
#   'sector_name_raw': 'basic life skills for youth and adults'},
#  '11231': {'category_description': {'all',
#    'and',
#    'children',
#    'cycle',
#    'education',
#    'elementary',
#    'first',
#    'for',
#    'formal',
#    'instruction',
#    'learning',
#    'materials',
#    'non',
#    'of',
#    'primary',
#    'provision',
#    'systematic'},
#   'category_description_raw': 'formal and non-formal primary education for children; all elementary and first cycle systematic instruction; provision of learning materials.',
#   'category_name': {'basic', 'education'},
#   'category_name_raw': 'basic education',
#   'sector_description': {'and',
#    'basic',
#    'education',
#    'for',
#    'formal',
#    'life',
#    'non',
#    'people',
#    'skills',
#    'young'},
#   'sector_description_raw': 'formal and non-formal education for basic life skills for young people.',
#   'sector_name': {'basic', 'for', 'life', 'skills', 'youth'},
#   'sector_name_raw': 'basic life skills for youth'},
#  '11232': {'category_description': {'all',
#    'and',
#    'children',
#    'cycle',
#    'education',
#    'elementary',
#    'first',
#    'for',
#    'formal',
#    'instruction',
#    'learning',
#    'materials',
#    'non',
#    'of',
#    'primary',
#    'provision',
#    'systematic'},
#   'category_description_raw': 'formal and non-formal primary education for children; all elementary and first cycle systematic instruction; provision of learning materials.',
#   'category_name': {'basic', 'education'},
#   'category_name_raw': 'basic education',
#   'sector_description': {'adults', 'education', 'for', 'formal', 'primary'},
#   'sector_description_raw': 'formal primary education for adults.',
#   'sector_name': {'adults', 'education', 'equivalent', 'for', 'primary'},
#   'sector_name_raw': 'primary education equivalent for adults'},
#  '11240': {'category_description': {'all',
#    'and',
#    'children',
#    'cycle',
#    'education',
#    'elementary',
#    'first',
#    'for',
#    'formal',
#    'instruction',
#    'learning',
#    'materials',
#    'non',
#    'of',
#    'primary',
#    'provision',
#    'systematic'},
#   'category_description_raw': 'formal and non-formal primary education for children; all elementary and first cycle systematic instruction; provision of learning materials.',
#   'category_name': {'basic', 'education'},
#   'category_name_raw': 'basic education',
#   'sector_description': {'and', 'education', 'formal', 'non', 'pre', 'school'},
#   'sector_description_raw': 'formal and non-formal pre-school education.',
#   'sector_name': {'childhood', 'early', 'education'},
#   'sector_name_raw': 'early childhood education'},
#  '11320': {'category_description': {'and',
#    'at',
#    'both',
#    'cycle',
#    'instruction',
#    'junior',
#    'levels',
#    'second',
#    'senior',
#    'systematic'},
#   'category_description_raw': 'second cycle systematic instruction at both junior and senior levels.',
#   'category_name': {'education', 'secondary'},
#   'category_name_raw': 'secondary education',
#   'sector_description': {'and',
#    'at',
#    'both',
#    'cycle',
#    'instruction',
#    'junior',
#    'levels',
#    'second',
#    'senior',
#    'systematic'},
#   'sector_description_raw': 'second cycle systematic instruction at both junior and senior levels.',
#   'sector_name': {'education', 'secondary'},
#   'sector_name_raw': 'secondary education'},
#  '11321': {'category_description': {'and',
#    'at',
#    'both',
#    'cycle',
#    'instruction',
#    'junior',
#    'levels',
#    'second',
#    'senior',
#    'systematic'},
#   'category_description_raw': 'second cycle systematic instruction at both junior and senior levels.',
#   'category_name': {'education', 'secondary'},
#   'category_name_raw': 'secondary education',
#   'sector_description': {'at',
#    'cycle',
#    'instruction',
#    'junior',
#    'level',
#    'second',
#    'systematic'},
#   'sector_description_raw': 'second cycle systematic instruction at junior level.',
#   'sector_name': {'education', 'lower', 'secondary'},
#   'sector_name_raw': 'lower secondary education'},
#  '11322': {'category_description': {'and',
#    'at',
#    'both',
#    'cycle',
#    'instruction',
#    'junior',
#    'levels',
#    'second',
#    'senior',
#    'systematic'},
#   'category_description_raw': 'second cycle systematic instruction at both junior and senior levels.',
#   'category_name': {'education', 'secondary'},
#   'category_name_raw': 'secondary education',
#   'sector_description': {'at',
#    'cycle',
#    'instruction',
#    'level',
#    'second',
#    'senior',
#    'systematic'},
#   'sector_description_raw': 'second cycle systematic instruction at senior level.',
#   'sector_name': {'education', 'secondary', 'upper'},
#   'sector_name_raw': 'upper secondary education'},
#  '11330': {'category_description': {'and',
#    'at',
#    'both',
#    'cycle',
#    'instruction',
#    'junior',
#    'levels',
#    'second',
#    'senior',
#    'systematic'},
#   'category_description_raw': 'second cycle systematic instruction at both junior and senior levels.',
#   'category_name': {'education', 'secondary'},
#   'category_name_raw': 'secondary education',
#   'sector_description': {'and',
#    'apprenticeships',
#    'education',
#    'elementary',
#    'including',
#    'informal',
#    'job',
#    'level',
#    'on',
#    'secondary',
#    'technical',
#    'the',
#    'training',
#    'vocational'},
#   'sector_description_raw': 'elementary vocational training and secondary level technical education; on-the job training; apprenticeships; including informal vocational training.',
#   'sector_name': {'training', 'vocational'},
#   'sector_name_raw': 'vocational training'},
#  '11420': {'category_description': {'and',
#    'at',
#    'colleges',
#    'degree',
#    'diploma',
#    'polytechnics',
#    'programmes',
#    'scholarships',
#    'universities'},
#   'category_description_raw': 'degree and diploma programmes at universities, colleges and polytechnics; scholarships.',
#   'category_name': {'education', 'post', 'secondary'},
#   'category_name_raw': 'post-secondary education',
#   'sector_description': {'and',
#    'at',
#    'colleges',
#    'degree',
#    'diploma',
#    'polytechnics',
#    'programmes',
#    'scholarships',
#    'universities'},
#   'sector_description_raw': 'degree and diploma programmes at universities, colleges and polytechnics; scholarships.',
#   'sector_name': {'education', 'higher'},
#   'sector_name_raw': 'higher education'},
#  '11430': {'category_description': {'and',
#    'at',
#    'colleges',
#    'degree',
#    'diploma',
#    'polytechnics',
#    'programmes',
#    'scholarships',
#    'universities'},
#   'category_description_raw': 'degree and diploma programmes at universities, colleges and polytechnics; scholarships.',
#   'category_name': {'education', 'post', 'secondary'},
#   'category_name_raw': 'post-secondary education',
#   'sector_description': {'and',
#    'in',
#    'level',
#    'professional',
#    'programmes',
#    'service',
#    'training',
#    'vocational'},
#   'sector_description_raw': 'professional-level vocational training programmes and in-service training.',
#   'sector_name': {'advanced', 'and', 'managerial', 'technical', 'training'},
#   'sector_name_raw': 'advanced technical and managerial training'},
#  '12110': {'category_description': {'activities',
#    'administration',
#    'advice',
#    'aid',
#    'and',
#    'building',
#    'capacity',
#    'health',
#    'institution',
#    'insurance',
#    'medical',
#    'ministries',
#    'planning',
#    'policy',
#    'programmes',
#    'public',
#    'sector',
#    'to',
#    'unspecified'},
#   'category_description_raw': 'health sector policy, planning and programmes; aid to health ministries, public health administration; institution capacity building and advice; medical insurance programmes; unspecified health activities.',
#   'category_name': {'general', 'health'},
#   'category_name_raw': 'health, general',
#   'sector_description': {'activities',
#    'administration',
#    'advice',
#    'aid',
#    'and',
#    'building',
#    'capacity',
#    'health',
#    'institution',
#    'insurance',
#    'medical',
#    'ministries',
#    'planning',
#    'policy',
#    'programmes',
#    'public',
#    'sector',
#    'to',
#    'unspecified'},
#   'sector_description_raw': 'health sector policy, planning and programmes; aid to health ministries, public health administration; institution capacity building and advice; medical insurance programmes; unspecified health activities.',
#   'sector_name': {'administrative', 'and', 'health', 'management', 'policy'},
#   'sector_name_raw': 'health policy and administrative management'},
#  '12181': {'category_description': {'activities',
#    'administration',
#    'advice',
#    'aid',
#    'and',
#    'building',
#    'capacity',
#    'health',
#    'institution',
#    'insurance',
#    'medical',
#    'ministries',
#    'planning',
#    'policy',
#    'programmes',
#    'public',
#    'sector',
#    'to',
#    'unspecified'},
#   'category_description_raw': 'health sector policy, planning and programmes; aid to health ministries, public health administration; institution capacity building and advice; medical insurance programmes; unspecified health activities.',
#   'category_name': {'general', 'health'},
#   'category_name_raw': 'health, general',
#   'sector_description': {'and',
#    'education',
#    'for',
#    'level',
#    'medical',
#    'services',
#    'tertiary',
#    'training'},
#   'sector_description_raw': 'medical education and training for tertiary level services.',
#   'sector_name': {'education', 'medical', 'training'},
#   'sector_name_raw': 'medical education/training'},
#  '12182': {'category_description': {'activities',
#    'administration',
#    'advice',
#    'aid',
#    'and',
#    'building',
#    'capacity',
#    'health',
#    'institution',
#    'insurance',
#    'medical',
#    'ministries',
#    'planning',
#    'policy',
#    'programmes',
#    'public',
#    'sector',
#    'to',
#    'unspecified'},
#   'category_description_raw': 'health sector policy, planning and programmes; aid to health ministries, public health administration; institution capacity building and advice; medical insurance programmes; unspecified health activities.',
#   'category_name': {'general', 'health'},
#   'category_name_raw': 'health, general',
#   'sector_description': {'basic',
#    'excluding',
#    'general',
#    'health',
#    'medical',
#    'research'},
#   'sector_description_raw': 'general medical research (excluding basic health research).',
#   'sector_name': {'medical', 'research'},
#   'sector_name_raw': 'medical research'},
#  '12191': {'category_description': {'activities',
#    'administration',
#    'advice',
#    'aid',
#    'and',
#    'building',
#    'capacity',
#    'health',
#    'institution',
#    'insurance',
#    'medical',
#    'ministries',
#    'planning',
#    'policy',
#    'programmes',
#    'public',
#    'sector',
#    'to',
#    'unspecified'},
#   'category_description_raw': 'health sector policy, planning and programmes; aid to health ministries, public health administration; institution capacity building and advice; medical insurance programmes; unspecified health activities.',
#   'category_name': {'general', 'health'},
#   'category_name_raw': 'health, general',
#   'sector_description': {'abuse',
#    'ambulances',
#    'and',
#    'care',
#    'clinics',
#    'control',
#    'dental',
#    'diseases',
#    'drug',
#    'equipment',
#    'excluding',
#    'health',
#    'hospitals',
#    'including',
#    'infectious',
#    'laboratories',
#    'medical',
#    'mental',
#    'narcotics',
#    'non',
#    'of',
#    'rehabilitation',
#    'services',
#    'specialised',
#    'substance',
#    'supplies',
#    'traffic'},
#   'sector_description_raw': 'laboratories, specialised clinics and hospitals (including equipment and supplies); ambulances; dental services; mental health care; medical rehabilitation; control of non-infectious diseases; drug and substance abuse control [excluding narcotics traffic control (16063)].',
#   'sector_name': {'medical', 'services'},
#   'sector_name_raw': 'medical services'},
#  '12220': {'category_description': {'and',
#    'basic',
#    'care',
#    'drugs',
#    'health',
#    'medicines',
#    'nursing',
#    'of',
#    'paramedical',
#    'primary',
#    'programmes',
#    'related',
#    'supply',
#    'to',
#    'vaccines'},
#   'category_description_raw': 'basic and primary health care programmes; paramedical and nursing care programmes; supply of drugs, medicines and vaccines related to basic health care.',
#   'category_name': {'basic', 'health'},
#   'category_name_raw': 'basic health',
#   'sector_description': {'and',
#    'basic',
#    'care',
#    'drugs',
#    'health',
#    'medicines',
#    'nursing',
#    'of',
#    'paramedical',
#    'primary',
#    'programmes',
#    'related',
#    'supply',
#    'to',
#    'vaccines'},
#   'sector_description_raw': 'basic and primary health care programmes; paramedical and nursing care programmes; supply of drugs, medicines and vaccines related to basic health care.',
#   'sector_name': {'basic', 'care', 'health'},
#   'sector_name_raw': 'basic health care'},
#  '12230': {'category_description': {'and',
#    'basic',
#    'care',
#    'drugs',
#    'health',
#    'medicines',
#    'nursing',
#    'of',
#    'paramedical',
#    'primary',
#    'programmes',
#    'related',
#    'supply',
#    'to',
#    'vaccines'},
#   'category_description_raw': 'basic and primary health care programmes; paramedical and nursing care programmes; supply of drugs, medicines and vaccines related to basic health care.',
#   'category_name': {'basic', 'health'},
#   'category_name_raw': 'basic health',
#   'sector_description': {'and',
#    'clinics',
#    'dispensaries',
#    'district',
#    'equipment',
#    'excluding',
#    'hospitals',
#    'level',
#    'medical',
#    'related',
#    'specialised'},
#   'sector_description_raw': 'district-level hospitals, clinics and dispensaries and related medical equipment; excluding specialised hospitals and clinics (12191).',
#   'sector_name': {'basic', 'health', 'infrastructure'},
#   'sector_name_raw': 'basic health infrastructure'},
#  '12240': {'category_description': {'and',
#    'basic',
#    'care',
#    'drugs',
#    'health',
#    'medicines',
#    'nursing',
#    'of',
#    'paramedical',
#    'primary',
#    'programmes',
#    'related',
#    'supply',
#    'to',
#    'vaccines'},
#   'category_description_raw': 'basic and primary health care programmes; paramedical and nursing care programmes; supply of drugs, medicines and vaccines related to basic health care.',
#   'category_name': {'basic', 'health'},
#   'category_name_raw': 'basic health',
#   'sector_description': {'a',
#    'and',
#    'breastfeeding',
#    'child',
#    'deficiencies',
#    'determination',
#    'direct',
#    'education',
#    'etc',
#    'feeding',
#    'food',
#    'foods',
#    'household',
#    'hygiene',
#    'iodine',
#    'iron',
#    'maternal',
#    'micro',
#    'monitoring',
#    'nutrient',
#    'nutrition',
#    'nutritional',
#    'of',
#    'programmes',
#    'provision',
#    'school',
#    'security',
#    'status',
#    'vitamin',
#    'weaning'},
#   'sector_description_raw': 'direct feeding programmes (maternal feeding, breastfeeding and weaning foods, child feeding, school feeding); determination of micro-nutrient deficiencies; provision of vitamin a, iodine, iron etc.; monitoring of nutritional status; nutrition and food hygiene education; household food security.',
#   'sector_name': {'basic', 'nutrition'},
#   'sector_name_raw': 'basic nutrition'},
#  '12250': {'category_description': {'and',
#    'basic',
#    'care',
#    'drugs',
#    'health',
#    'medicines',
#    'nursing',
#    'of',
#    'paramedical',
#    'primary',
#    'programmes',
#    'related',
#    'supply',
#    'to',
#    'vaccines'},
#   'category_description_raw': 'basic and primary health care programmes; paramedical and nursing care programmes; supply of drugs, medicines and vaccines related to basic health care.',
#   'category_name': {'basic', 'health'},
#   'category_name_raw': 'basic health',
#   'sector_description': {'aids',
#    'and',
#    'bacteria',
#    'blindness',
#    'borne',
#    'by',
#    'control',
#    'diarrheal',
#    'diseases',
#    'e',
#    'etc',
#    'except',
#    'g',
#    'guinea',
#    'helminthiasis',
#    'hiv',
#    'immunisation',
#    'includes',
#    'infectious',
#    'it',
#    'malaria',
#    'mycosis',
#    'of',
#    'other',
#    'parasite',
#    'pediculosis',
#    'prevention',
#    'river',
#    'stds',
#    'tuberculosis',
#    'vector',
#    'viral',
#    'viruses',
#    'worm',
#    'zoonosis'},
#   'sector_description_raw': 'immunisation; prevention and control of infectious and parasite diseases, except malaria (12262), tuberculosis (12263), hiv/aids and other stds (13040). it includes diarrheal diseases, vector-borne diseases (e.g. river blindness and guinea worm), viral diseases, mycosis, helminthiasis, zoonosis, diseases by other bacteria and viruses, pediculosis, etc.',
#   'sector_name': {'control', 'disease', 'infectious'},
#   'sector_name_raw': 'infectious disease control'},
#  '12261': {'category_description': {'and',
#    'basic',
#    'care',
#    'drugs',
#    'health',
#    'medicines',
#    'nursing',
#    'of',
#    'paramedical',
#    'primary',
#    'programmes',
#    'related',
#    'supply',
#    'to',
#    'vaccines'},
#   'category_description_raw': 'basic and primary health care programmes; paramedical and nursing care programmes; supply of drugs, medicines and vaccines related to basic health care.',
#   'category_name': {'basic', 'health'},
#   'category_name_raw': 'basic health',
#   'sector_description': {'and',
#    'awareness',
#    'campaigns',
#    'education',
#    'facilities',
#    'for',
#    'handwashing',
#    'health',
#    'hygiene',
#    'improved',
#    'improving',
#    'including',
#    'information',
#    'knowledge',
#    'of',
#    'personal',
#    'population',
#    'practices',
#    'promotion',
#    'public',
#    'sanitation',
#    'soap',
#    'the',
#    'training',
#    'use',
#    'with'},
#   'sector_description_raw': 'information, education and training of the population for improving health knowledge and practices; public health and awareness campaigns; promotion of improved personal hygiene practices, including use of sanitation facilities and handwashing with soap.',
#   'sector_name': {'education', 'health'},
#   'sector_name_raw': 'health education'},
#  '12262': {'category_description': {'and',
#    'basic',
#    'care',
#    'drugs',
#    'health',
#    'medicines',
#    'nursing',
#    'of',
#    'paramedical',
#    'primary',
#    'programmes',
#    'related',
#    'supply',
#    'to',
#    'vaccines'},
#   'category_description_raw': 'basic and primary health care programmes; paramedical and nursing care programmes; supply of drugs, medicines and vaccines related to basic health care.',
#   'category_name': {'basic', 'health'},
#   'category_name_raw': 'basic health',
#   'sector_description': {'and', 'control', 'malaria', 'of', 'prevention'},
#   'sector_description_raw': 'prevention and control of malaria.',
#   'sector_name': {'control', 'malaria'},
#   'sector_name_raw': 'malaria control'},
#  '12263': {'category_description': {'and',
#    'basic',
#    'care',
#    'drugs',
#    'health',
#    'medicines',
#    'nursing',
#    'of',
#    'paramedical',
#    'primary',
#    'programmes',
#    'related',
#    'supply',
#    'to',
#    'vaccines'},
#   'category_description_raw': 'basic and primary health care programmes; paramedical and nursing care programmes; supply of drugs, medicines and vaccines related to basic health care.',
#   'category_name': {'basic', 'health'},
#   'category_name_raw': 'basic health',
#   'sector_description': {'and',
#    'control',
#    'immunisation',
#    'of',
#    'prevention',
#    'tuberculosis'},
#   'sector_description_raw': 'immunisation, prevention and control of tuberculosis.',
#   'sector_name': {'control', 'tuberculosis'},
#   'sector_name_raw': 'tuberculosis control'},
#  '12281': {'category_description': {'and',
#    'basic',
#    'care',
#    'drugs',
#    'health',
#    'medicines',
#    'nursing',
#    'of',
#    'paramedical',
#    'primary',
#    'programmes',
#    'related',
#    'supply',
#    'to',
#    'vaccines'},
#   'category_description_raw': 'basic and primary health care programmes; paramedical and nursing care programmes; supply of drugs, medicines and vaccines related to basic health care.',
#   'category_name': {'basic', 'health'},
#   'category_name_raw': 'basic health',
#   'sector_description': {'basic',
#    'care',
#    'for',
#    'health',
#    'of',
#    'services',
#    'staff',
#    'training'},
#   'sector_description_raw': 'training of health staff for basic health care services.',
#   'sector_name': {'development', 'health', 'personnel'},
#   'sector_name_raw': 'health personnel development'},
#  '13010': {'category_description': {'activities',
#    'analysis',
#    'census',
#    'data',
#    'demographic',
#    'development',
#    'health',
#    'migration',
#    'policies',
#    'population',
#    'registration',
#    'reproductive',
#    'research',
#    'unspecified',
#    'vital',
#    'work'},
#   'category_description_raw': 'population/development policies; census work, vital registration; migration data; demographic research/analysis; reproductive health research; unspecified population activities.',
#   'category_name': {'and',
#    'health',
#    'policies',
#    'population',
#    'programmes',
#    'reproductive'},
#   'category_name_raw': 'population policies/ programmes and reproductive health',
#   'sector_description': {'activities',
#    'analysis',
#    'census',
#    'data',
#    'demographic',
#    'development',
#    'health',
#    'migration',
#    'policies',
#    'population',
#    'registration',
#    'reproductive',
#    'research',
#    'unspecified',
#    'vital',
#    'work'},
#   'sector_description_raw': 'population/development policies; census work, vital registration; migration data; demographic research/analysis; reproductive health research; unspecified population activities.',
#   'sector_name': {'administrative',
#    'and',
#    'management',
#    'policy',
#    'population'},
#   'sector_name_raw': 'population policy and administrative management'},
#  '13020': {'category_description': {'activities',
#    'analysis',
#    'census',
#    'data',
#    'demographic',
#    'development',
#    'health',
#    'migration',
#    'policies',
#    'population',
#    'registration',
#    'reproductive',
#    'research',
#    'unspecified',
#    'vital',
#    'work'},
#   'category_description_raw': 'population/development policies; census work, vital registration; migration data; demographic research/analysis; reproductive health research; unspecified population activities.',
#   'category_name': {'and',
#    'health',
#    'policies',
#    'population',
#    'programmes',
#    'reproductive'},
#   'category_name_raw': 'population policies/ programmes and reproductive health',
#   'sector_description': {'abortion',
#    'activities',
#    'and',
#    'care',
#    'consequences',
#    'delivery',
#    'health',
#    'including',
#    'infertility',
#    'management',
#    'motherhood',
#    'of',
#    'postnatal',
#    'prenatal',
#    'prevention',
#    'promotion',
#    'reproductive',
#    'safe',
#    'treatment'},
#   'sector_description_raw': 'promotion of reproductive health; prenatal and postnatal care including delivery; prevention and treatment of infertility; prevention and management of consequences of abortion; safe motherhood activities.',
#   'sector_name': {'care', 'health', 'reproductive'},
#   'sector_name_raw': 'reproductive health care'},
#  '13030': {'category_description': {'activities',
#    'analysis',
#    'census',
#    'data',
#    'demographic',
#    'development',
#    'health',
#    'migration',
#    'policies',
#    'population',
#    'registration',
#    'reproductive',
#    'research',
#    'unspecified',
#    'vital',
#    'work'},
#   'category_description_raw': 'population/development policies; census work, vital registration; migration data; demographic research/analysis; reproductive health research; unspecified population activities.',
#   'category_name': {'and',
#    'health',
#    'policies',
#    'population',
#    'programmes',
#    'reproductive'},
#   'category_name_raw': 'population policies/ programmes and reproductive health',
#   'sector_description': {'activities',
#    'and',
#    'building',
#    'capacity',
#    'communication',
#    'contraceptives',
#    'counselling',
#    'delivery',
#    'education',
#    'family',
#    'iec',
#    'including',
#    'information',
#    'of',
#    'planning',
#    'services',
#    'training'},
#   'sector_description_raw': 'family planning services including counselling; information, education and communication (iec) activities; delivery of contraceptives; capacity building and training.',
#   'sector_name': {'family', 'planning'},
#   'sector_name_raw': 'family planning'},
#  '13040': {'category_description': {'activities',
#    'analysis',
#    'census',
#    'data',
#    'demographic',
#    'development',
#    'health',
#    'migration',
#    'policies',
#    'population',
#    'registration',
#    'reproductive',
#    'research',
#    'unspecified',
#    'vital',
#    'work'},
#   'category_description_raw': 'population/development policies; census work, vital registration; migration data; demographic research/analysis; reproductive health research; unspecified population activities.',
#   'category_name': {'and',
#    'health',
#    'policies',
#    'population',
#    'programmes',
#    'reproductive'},
#   'category_name_raw': 'population policies/ programmes and reproductive health',
#   'sector_description': {'activities',
#    'aids',
#    'all',
#    'and',
#    'care',
#    'communication',
#    'control',
#    'diseases',
#    'e',
#    'education',
#    'g',
#    'hiv',
#    'information',
#    'prevention',
#    'related',
#    'sexually',
#    'testing',
#    'to',
#    'transmitted',
#    'treatment'},
#   'sector_description_raw': 'all activities related to sexually transmitted diseases and hiv/aids control e.g. information, education and communication; testing; prevention; treatment, care.',
#   'sector_name': {'aids', 'control', 'hiv', 'including', 'std'},
#   'sector_name_raw': 'std control including hiv/aids'},
#  '13081': {'category_description': {'activities',
#    'analysis',
#    'census',
#    'data',
#    'demographic',
#    'development',
#    'health',
#    'migration',
#    'policies',
#    'population',
#    'registration',
#    'reproductive',
#    'research',
#    'unspecified',
#    'vital',
#    'work'},
#   'category_description_raw': 'population/development policies; census work, vital registration; migration data; demographic research/analysis; reproductive health research; unspecified population activities.',
#   'category_name': {'and',
#    'health',
#    'policies',
#    'population',
#    'programmes',
#    'reproductive'},
#   'category_name_raw': 'population policies/ programmes and reproductive health',
#   'sector_description': {'and',
#    'care',
#    'education',
#    'for',
#    'health',
#    'of',
#    'population',
#    'reproductive',
#    'services',
#    'staff',
#    'training'},
#   'sector_description_raw': 'education and training of health staff for population and reproductive health care services.',
#   'sector_name': {'and',
#    'development',
#    'for',
#    'health',
#    'personnel',
#    'population',
#    'reproductive'},
#   'sector_name_raw': 'personnel development for population and reproductive health'},
#  '14010': {'category_description': {'activities',
#    'and',
#    'approach',
#    'as',
#    'below',
#    'box',
#    'capacity',
#    'development',
#    'governance',
#    'including',
#    'institutional',
#    'integrated',
#    'iwrm',
#    'legislation',
#    'management',
#    'of',
#    'planning',
#    'policy',
#    'regulation',
#    'resource',
#    'sector',
#    'see',
#    'supporting',
#    'the',
#    'transboundary',
#    'water',
#    'well'},
#   'category_description_raw': 'water sector policy and governance, including legislation, regulation, planning and management as well as transboundary management of water; institutional capacity development; activities supporting the integrated water resource management approach (iwrm: see box below).',
#   'category_name': {'and', 'sanitation', 'water'},
#   'category_name_raw': 'water and sanitation',
#   'sector_description': {'activities',
#    'and',
#    'approach',
#    'as',
#    'below',
#    'box',
#    'capacity',
#    'development',
#    'governance',
#    'including',
#    'institutional',
#    'integrated',
#    'iwrm',
#    'legislation',
#    'management',
#    'of',
#    'planning',
#    'policy',
#    'regulation',
#    'resource',
#    'sector',
#    'see',
#    'supporting',
#    'the',
#    'transboundary',
#    'water',
#    'well'},
#   'sector_description_raw': 'water sector policy and governance, including legislation, regulation, planning and management as well as transboundary management of water; institutional capacity development; activities supporting the integrated water resource management approach (iwrm: see box below).',
#   'sector_name': {'administrative',
#    'and',
#    'management',
#    'policy',
#    'sector',
#    'water'},
#   'sector_name_raw': 'water sector policy and administrative management'},
#  '14015': {'category_description': {'activities',
#    'and',
#    'approach',
#    'as',
#    'below',
#    'box',
#    'capacity',
#    'development',
#    'governance',
#    'including',
#    'institutional',
#    'integrated',
#    'iwrm',
#    'legislation',
#    'management',
#    'of',
#    'planning',
#    'policy',
#    'regulation',
#    'resource',
#    'sector',
#    'see',
#    'supporting',
#    'the',
#    'transboundary',
#    'water',
#    'well'},
#   'category_description_raw': 'water sector policy and governance, including legislation, regulation, planning and management as well as transboundary management of water; institutional capacity development; activities supporting the integrated water resource management approach (iwrm: see box below).',
#   'category_name': {'and', 'sanitation', 'water'},
#   'category_name_raw': 'water and sanitation',
#   'sector_description': {'and',
#    'coastal',
#    'collection',
#    'conservation',
#    'contamination',
#    'creation',
#    'data',
#    'etc',
#    'ground',
#    'inland',
#    'knowledge',
#    'lakes',
#    'of',
#    'on',
#    'prevention',
#    'qualitative',
#    'quantitative',
#    'rehabilitation',
#    'resources',
#    'rivers',
#    'sharing',
#    'surface',
#    'usage',
#    'water',
#    'waters'},
#   'sector_description_raw': 'collection and usage of quantitative and qualitative data on water resources; creation and sharing of water knowledge; conservation and rehabilitation of inland surface waters (rivers, lakes etc.), ground water and coastal waters; prevention of water contamination.',
#   'sector_name': {'collection',
#    'conservation',
#    'data',
#    'including',
#    'resources',
#    'water'},
#   'sector_name_raw': 'water resources conservation (including data collection)'},
#  '14020': {'category_description': {'activities',
#    'and',
#    'approach',
#    'as',
#    'below',
#    'box',
#    'capacity',
#    'development',
#    'governance',
#    'including',
#    'institutional',
#    'integrated',
#    'iwrm',
#    'legislation',
#    'management',
#    'of',
#    'planning',
#    'policy',
#    'regulation',
#    'resource',
#    'sector',
#    'see',
#    'supporting',
#    'the',
#    'transboundary',
#    'water',
#    'well'},
#   'category_description_raw': 'water sector policy and governance, including legislation, regulation, planning and management as well as transboundary management of water; institutional capacity development; activities supporting the integrated water resource management approach (iwrm: see box below).',
#   'category_name': {'and', 'sanitation', 'water'},
#   'category_name_raw': 'water and sanitation',
#   'sector_description': {'according',
#    'and',
#    'are',
#    'be',
#    'cannot',
#    'codes',
#    'components',
#    'hygiene',
#    'identified',
#    'individually',
#    'known',
#    'programmes',
#    'purpose',
#    'reported',
#    'respective',
#    'sanitation',
#    'should',
#    'supply',
#    'their',
#    'they',
#    'to',
#    'under',
#    'water',
#    'when',
#    'where'},
#   'sector_description_raw': 'programmes where components according to 14021 and 14022 cannot be identified. when components are known, they should individually be reported under their respective purpose codes: water supply (14021), sanitation (14022), and hygiene (12261).',
#   'sector_name': {'and', 'large', 'sanitation', 'supply', 'systems', 'water'},
#   'sector_name_raw': 'water supply and sanitation - large systems'},
#  '14021': {'category_description': {'activities',
#    'and',
#    'approach',
#    'as',
#    'below',
#    'box',
#    'capacity',
#    'development',
#    'governance',
#    'including',
#    'institutional',
#    'integrated',
#    'iwrm',
#    'legislation',
#    'management',
#    'of',
#    'planning',
#    'policy',
#    'regulation',
#    'resource',
#    'sector',
#    'see',
#    'supporting',
#    'the',
#    'transboundary',
#    'water',
#    'well'},
#   'category_description_raw': 'water sector policy and governance, including legislation, regulation, planning and management as well as transboundary management of water; institutional capacity development; activities supporting the integrated water resource management approach (iwrm: see box below).',
#   'category_name': {'and', 'sanitation', 'water'},
#   'category_name_raw': 'water and sanitation',
#   'sector_description': {'and',
#    'conveyance',
#    'distribution',
#    'intake',
#    'large',
#    'plants',
#    'potable',
#    'pumping',
#    'scale',
#    'stations',
#    'storage',
#    'supply',
#    'systems',
#    'transmission',
#    'treatment',
#    'water',
#    'works'},
#   'sector_description_raw': 'potable water treatment plants; intake works; storage; water supply pumping stations; large scale transmission / conveyance and distribution systems.',
#   'sector_name': {'large', 'supply', 'systems', 'water'},
#   'sector_name_raw': 'water supply - large systems'},
#  '14022': {'category_description': {'activities',
#    'and',
#    'approach',
#    'as',
#    'below',
#    'box',
#    'capacity',
#    'development',
#    'governance',
#    'including',
#    'institutional',
#    'integrated',
#    'iwrm',
#    'legislation',
#    'management',
#    'of',
#    'planning',
#    'policy',
#    'regulation',
#    'resource',
#    'sector',
#    'see',
#    'supporting',
#    'the',
#    'transboundary',
#    'water',
#    'well'},
#   'category_description_raw': 'water sector policy and governance, including legislation, regulation, planning and management as well as transboundary management of water; institutional capacity development; activities supporting the integrated water resource management approach (iwrm: see box below).',
#   'category_name': {'and', 'sanitation', 'water'},
#   'category_name_raw': 'water and sanitation',
#   'sector_description': {'and',
#    'domestic',
#    'including',
#    'industrial',
#    'large',
#    'plants',
#    'pumping',
#    'scale',
#    'sewage',
#    'sewerage',
#    'sewers',
#    'stations',
#    'treatment',
#    'trunk',
#    'waste',
#    'water'},
#   'sector_description_raw': 'large scale sewerage including trunk sewers and sewage pumping stations; domestic and industrial waste water treatment plants.',
#   'sector_name': {'large', 'sanitation', 'systems'},
#   'sector_name_raw': 'sanitation - large systems'},
#  '14030': {'category_description': {'activities',
#    'and',
#    'approach',
#    'as',
#    'below',
#    'box',
#    'capacity',
#    'development',
#    'governance',
#    'including',
#    'institutional',
#    'integrated',
#    'iwrm',
#    'legislation',
#    'management',
#    'of',
#    'planning',
#    'policy',
#    'regulation',
#    'resource',
#    'sector',
#    'see',
#    'supporting',
#    'the',
#    'transboundary',
#    'water',
#    'well'},
#   'category_description_raw': 'water sector policy and governance, including legislation, regulation, planning and management as well as transboundary management of water; institutional capacity development; activities supporting the integrated water resource management approach (iwrm: see box below).',
#   'category_name': {'and', 'sanitation', 'water'},
#   'category_name_raw': 'water and sanitation',
#   'sector_description': {'according',
#    'and',
#    'are',
#    'be',
#    'cannot',
#    'codes',
#    'components',
#    'hygiene',
#    'identified',
#    'individually',
#    'known',
#    'programmes',
#    'purpose',
#    'reported',
#    'respective',
#    'sanitation',
#    'should',
#    'supply',
#    'their',
#    'they',
#    'to',
#    'under',
#    'water',
#    'when',
#    'where'},
#   'sector_description_raw': 'programmes where components according to 14031 and 14032 cannot be identified. when components are known, they should individually be reported under their respective purpose codes: water supply (14031), sanitation (14032), and hygiene (12261).',
#   'sector_name': {'and', 'basic', 'drinking', 'sanitation', 'supply', 'water'},
#   'sector_name_raw': 'basic drinking water supply and basic sanitation'},
#  '14031': {'category_description': {'activities',
#    'and',
#    'approach',
#    'as',
#    'below',
#    'box',
#    'capacity',
#    'development',
#    'governance',
#    'including',
#    'institutional',
#    'integrated',
#    'iwrm',
#    'legislation',
#    'management',
#    'of',
#    'planning',
#    'policy',
#    'regulation',
#    'resource',
#    'sector',
#    'see',
#    'supporting',
#    'the',
#    'transboundary',
#    'water',
#    'well'},
#   'category_description_raw': 'water sector policy and governance, including legislation, regulation, planning and management as well as transboundary management of water; institutional capacity development; activities supporting the integrated water resource management approach (iwrm: see box below).',
#   'category_name': {'and', 'sanitation', 'water'},
#   'category_name_raw': 'water and sanitation',
#   'sector_description': {'and',
#    'catchments',
#    'collection',
#    'connections',
#    'distribution',
#    'fed',
#    'fog',
#    'gravity',
#    'handpumps',
#    'harvesting',
#    'including',
#    'local',
#    'neighbourhood',
#    'networks',
#    'of',
#    'points',
#    'rainwater',
#    'rural',
#    'schemes',
#    'shared',
#    'small',
#    'spring',
#    'storage',
#    'supply',
#    'systems',
#    'tanks',
#    'those',
#    'typically',
#    'urban',
#    'use',
#    'using',
#    'water',
#    'with'},
#   'sector_description_raw': 'rural water supply schemes using handpumps, spring catchments, gravity-fed systems, rainwater collection and fog harvesting, storage tanks, small distribution systems typically with shared connections/points of use. urban schemes using handpumps and local neighbourhood networks including those with shared connections.',
#   'sector_name': {'basic', 'drinking', 'supply', 'water'},
#   'sector_name_raw': 'basic drinking water supply'},
#  '14032': {'category_description': {'activities',
#    'and',
#    'approach',
#    'as',
#    'below',
#    'box',
#    'capacity',
#    'development',
#    'governance',
#    'including',
#    'institutional',
#    'integrated',
#    'iwrm',
#    'legislation',
#    'management',
#    'of',
#    'planning',
#    'policy',
#    'regulation',
#    'resource',
#    'sector',
#    'see',
#    'supporting',
#    'the',
#    'transboundary',
#    'water',
#    'well'},
#   'category_description_raw': 'water sector policy and governance, including legislation, regulation, planning and management as well as transboundary management of water; institutional capacity development; activities supporting the integrated water resource management approach (iwrm: see box below).',
#   'category_name': {'and', 'sanitation', 'water'},
#   'category_name_raw': 'water and sanitation',
#   'sector_description': {'activities',
#    'alternative',
#    'and',
#    'code',
#    'community',
#    'construction',
#    'disposal',
#    'facilities',
#    'for',
#    'household',
#    'hygiene',
#    'improved',
#    'in',
#    'including',
#    'investments',
#    'latrines',
#    'of',
#    'on',
#    'personal',
#    'practices',
#    'promoting',
#    'promotion',
#    'sanitation',
#    'site',
#    'systems',
#    'the',
#    'these',
#    'use'},
#   'sector_description_raw': 'latrines, on-site disposal and alternative sanitation systems, including the promotion of household and community investments in the construction of these facilities. (use code 12261 for activities promoting improved personal hygiene practices.)',
#   'sector_name': {'basic', 'sanitation'},
#   'sector_name_raw': 'basic sanitation'},
#  '14040': {'category_description': {'activities',
#    'and',
#    'approach',
#    'as',
#    'below',
#    'box',
#    'capacity',
#    'development',
#    'governance',
#    'including',
#    'institutional',
#    'integrated',
#    'iwrm',
#    'legislation',
#    'management',
#    'of',
#    'planning',
#    'policy',
#    'regulation',
#    'resource',
#    'sector',
#    'see',
#    'supporting',
#    'the',
#    'transboundary',
#    'water',
#    'well'},
#   'category_description_raw': 'water sector policy and governance, including legislation, regulation, planning and management as well as transboundary management of water; institutional capacity development; activities supporting the integrated water resource management approach (iwrm: see box below).',
#   'category_name': {'and', 'sanitation', 'water'},
#   'category_name_raw': 'water and sanitation',
#   'sector_description': {'activities',
#    'and',
#    'basin',
#    'control',
#    'dams',
#    'excluding',
#    'flow',
#    'focused',
#    'for',
#    'hydropower',
#    'infrastructure',
#    'institutional',
#    'integrated',
#    'irrigation',
#    'primarily',
#    'projects',
#    'related',
#    'reservoirs',
#    'river',
#    'to',
#    'transport'},
#   'sector_description_raw': 'infrastructure-focused integrated river basin projects and related institutional activities; river flow control; dams and reservoirs [excluding dams primarily for irrigation (31140) and hydropower (23220) and activities related to river transport (21040)].',
#   'sector_name': {'basins', 'development', 'river'},
# ...
#   'sector_description': {'agent',
#    'an',
#    'benefits',
#    'debt',
#    'development',
#    'e',
#    'external',
#    'for',
#    'i',
#    'is',
#    'not',
#    'purposes',
#    'specifically',
#    'swap',
#    'the',
#    'where'},
#   'sector_description_raw': 'where the debt swap benefits an external agent i.e. is not specifically for development purposes.',
#   'sector_name': {'debt', 'other', 'swap'},
#   'sector_name_raw': 'other debt swap'},
#  '60063': {'category_description': {'actions',
#    'below',
#    'code',
#    'falling',
#    'headings',
#    'outside',
#    'the'},
#   'category_description_raw': 'actions falling outside the code headings below.',
#   'category_name': {'debt', 'relief'},
#   'category_name_raw': 'debt relief',
#   'sector_description': {'cancellation',
#    'debt',
#    'for',
#    'of',
#    'purchase',
#    'purpose',
#    'the'},
#   'sector_description_raw': 'purchase of debt for the purpose of cancellation.',
#   'sector_name': {'back', 'buy', 'debt'},
#   'sector_name_raw': 'debt buy-back'},
#  '72010': {'category_description': {'affected',
#    'and',
#    'assistance',
#    'benefit',
#    'countries',
#    'developing',
#    'displaced',
#    'facilitate',
#    'food',
#    'for',
#    'health',
#    'in',
#    'internally',
#    'items',
#    'livelihoods',
#    'lives',
#    'medicines',
#    'non',
#    'normal',
#    'of',
#    'or',
#    'other',
#    'people',
#    'protection',
#    'refugees',
#    'relief',
#    'return',
#    'sanitation',
#    'services',
#    'shelter',
#    'supply',
#    'than',
#    'the',
#    'to',
#    'water'},
#   'category_description_raw': 'shelter, water, sanitation and health services, supply of medicines and other non-food relief items for the benefit of affected people and to facilitate the return to normal lives and livelihoods; assistance to refugees and internally displaced people in developing countries other than for food (72040) or protection (72050).',
#   'category_name': {'emergency', 'response'},
#   'category_name_raw': 'emergency response',
#   'sector_description': {'affected',
#    'and',
#    'assistance',
#    'benefit',
#    'countries',
#    'developing',
#    'displaced',
#    'facilitate',
#    'food',
#    'for',
#    'health',
#    'in',
#    'internally',
#    'items',
#    'livelihoods',
#    'lives',
#    'medicines',
#    'non',
#    'normal',
#    'of',
#    'or',
#    'other',
#    'people',
#    'protection',
#    'refugees',
#    'relief',
#    'return',
#    'sanitation',
#    'services',
#    'shelter',
#    'supply',
#    'than',
#    'the',
#    'to',
#    'water'},
#   'sector_description_raw': 'shelter, water, sanitation and health services, supply of medicines and other non-food relief items for the benefit of affected people and to facilitate the return to normal lives and livelihoods; assistance to refugees and internally displaced people in developing countries other than for food (72040) or protection (72050).',
#   'sector_name': {'and', 'assistance', 'material', 'relief', 'services'},
#   'sector_name_raw': 'material relief assistance and services'},
#  '72040': {'category_description': {'affected',
#    'and',
#    'assistance',
#    'benefit',
#    'countries',
#    'developing',
#    'displaced',
#    'facilitate',
#    'food',
#    'for',
#    'health',
#    'in',
#    'internally',
#    'items',
#    'livelihoods',
#    'lives',
#    'medicines',
#    'non',
#    'normal',
#    'of',
#    'or',
#    'other',
#    'people',
#    'protection',
#    'refugees',
#    'relief',
#    'return',
#    'sanitation',
#    'services',
#    'shelter',
#    'supply',
#    'than',
#    'the',
#    'to',
#    'water'},
#   'category_description_raw': 'shelter, water, sanitation and health services, supply of medicines and other non-food relief items for the benefit of affected people and to facilitate the return to normal lives and livelihoods; assistance to refugees and internally displaced people in developing countries other than for food (72040) or protection (72050).',
#   'category_name': {'emergency', 'response'},
#   'category_name_raw': 'emergency response',
#   'sector_description': {'affected',
#    'aid',
#    'assistance',
#    'by',
#    'distribution',
#    'emergency',
#    'excludes',
#    'feeding',
#    'food',
#    'for',
#    'free',
#    'general',
#    'groups',
#    'non',
#    'normally',
#    'or',
#    'population',
#    'programmes',
#    'relief',
#    'security',
#    'short',
#    'situations',
#    'special',
#    'supplementary',
#    'targeted',
#    'term',
#    'to'},
#   'sector_description_raw': 'food aid normally for general free distribution or special supplementary feeding programmes; short-term relief to targeted population groups affected by emergency situations. excludes non-emergency food security assistance programmes/food aid (52010).',
#   'sector_name': {'aid', 'emergency', 'food'},
#   'sector_name_raw': 'emergency food aid'},
#  '72050': {'category_description': {'affected',
#    'and',
#    'assistance',
#    'benefit',
#    'countries',
#    'developing',
#    'displaced',
#    'facilitate',
#    'food',
#    'for',
#    'health',
#    'in',
#    'internally',
#    'items',
#    'livelihoods',
#    'lives',
#    'medicines',
#    'non',
#    'normal',
#    'of',
#    'or',
#    'other',
#    'people',
#    'protection',
#    'refugees',
#    'relief',
#    'return',
#    'sanitation',
#    'services',
#    'shelter',
#    'supply',
#    'than',
#    'the',
#    'to',
#    'water'},
#   'category_description_raw': 'shelter, water, sanitation and health services, supply of medicines and other non-food relief items for the benefit of affected people and to facilitate the return to normal lives and livelihoods; assistance to refugees and internally displaced people in developing countries other than for food (72040) or protection (72050).',
#   'category_name': {'emergency', 'response'},
#   'category_name_raw': 'emergency response',
#   'sector_description': {'activities',
#    'aid',
#    'and',
#    'are',
#    'as',
#    'being',
#    'civilians',
#    'co',
#    'communications',
#    'delivery',
#    'designed',
#    'dignity',
#    'display',
#    'force',
#    'hostilities',
#    'humanitarian',
#    'in',
#    'including',
#    'integrity',
#    'logistics',
#    'longer',
#    'measures',
#    'no',
#    'not',
#    'oda',
#    'of',
#    'or',
#    'ordinate',
#    'part',
#    'persons',
#    'promote',
#    'property',
#    'protect',
#    'reportable',
#    'safety',
#    'security',
#    'systems',
#    'taking',
#    'the',
#    'those',
#    'through',
#    'to',
#    'use',
#    'well'},
#   'sector_description_raw': 'measures to co-ordinate delivery of humanitarian aid, including logistics and communications systems; measures to promote and protect the safety, well- being, dignity and integrity of civilians and those no longer taking part in hostilities. (activities designed to protect the security of persons or property through the use or display of force are not reportable as oda.)',
#   'sector_name': {'and',
#    'co',
#    'ordination',
#    'protection',
#    'relief',
#    'services',
#    'support'},
#   'sector_name_raw': 'relief co-ordination; protection and support services'},
#  '73010': {'category_description': {'a',
#    'after',
#    'aftermath',
#    'an',
#    'and',
#    'as',
#    'bridges',
#    'care',
#    'conflict',
#    'construction',
#    'counselling',
#    'develop',
#    'e',
#    'economic',
#    'emergencies',
#    'emergency',
#    'employment',
#    'enable',
#    'essential',
#    'existing',
#    'facilitate',
#    'facilities',
#    'g',
#    'health',
#    'in',
#    'infrastructure',
#    'limited',
#    'livelihood',
#    'new',
#    'of',
#    'or',
#    'populations',
#    'ports',
#    'pre',
#    'previous',
#    'programmes',
#    'reconstruction',
#    'rehabilitation',
#    'repair',
#    'restoration',
#    'restoring',
#    'return',
#    'roads',
#    'sanitation',
#    'services',
#    'shelter',
#    'short',
#    'situation',
#    'social',
#    'such',
#    'term',
#    'the',
#    'their',
#    'to',
#    'transition',
#    'trauma',
#    'treatment',
#    'wake',
#    'water',
#    'work'},
#   'category_description_raw': 'short-term reconstruction work after emergency or conflict limited to restoring pre-existing infrastructure (e.g. repair or construction of roads, bridges and ports, restoration of essential facilities, such as water and sanitation, shelter, health care services); social and economic rehabilitation in the aftermath of emergencies to facilitate transition and enable populations to return to their previous livelihood or develop a new livelihood in the wake of an emergency situation (e.g. trauma counselling and treatment, employment programmes).',
#   'category_name': {'and', 'reconstruction', 'rehabilitation', 'relief'},
#   'category_name_raw': 'reconstruction relief and rehabilitation',
#   'sector_description': {'a',
#    'after',
#    'aftermath',
#    'an',
#    'and',
#    'as',
#    'bridges',
#    'care',
#    'conflict',
#    'construction',
#    'counselling',
#    'develop',
#    'e',
#    'economic',
#    'emergencies',
#    'emergency',
#    'employment',
#    'enable',
#    'essential',
#    'existing',
#    'facilitate',
#    'facilities',
#    'g',
#    'health',
#    'in',
#    'infrastructure',
#    'limited',
#    'livelihood',
#    'new',
#    'of',
#    'or',
#    'populations',
#    'ports',
#    'pre',
#    'previous',
#    'programmes',
#    'reconstruction',
#    'rehabilitation',
#    'repair',
#    'restoration',
#    'restoring',
#    'return',
#    'roads',
#    'sanitation',
#    'services',
#    'shelter',
#    'short',
#    'situation',
#    'social',
#    'such',
#    'term',
#    'the',
#    'their',
#    'to',
#    'transition',
#    'trauma',
#    'treatment',
#    'wake',
#    'water',
#    'work'},
#   'sector_description_raw': 'short-term reconstruction work after emergency or conflict limited to restoring pre-existing infrastructure (e.g. repair or construction of roads, bridges and ports, restoration of essential facilities, such as water and sanitation, shelter, health care services); social and economic rehabilitation in the aftermath of emergencies to facilitate transition and enable populations to return to their previous livelihood or develop a new livelihood in the wake of an emergency situation (e.g. trauma counselling and treatment, employment programmes).',
#   'sector_name': {'and', 'reconstruction', 'rehabilitation', 'relief'},
#   'sector_name_raw': 'reconstruction relief and rehabilitation'},
#  '74010': {'category_description': {'activities',
#    'and',
#    'cartography',
#    'construction',
#    'contingency',
#    'developing',
#    'disaster',
#    'displacement',
#    'e',
#    'early',
#    'emergency',
#    'for',
#    'forced',
#    'g',
#    'including',
#    'knowledge',
#    'legal',
#    'natural',
#    'norms',
#    'planning',
#    'preparations',
#    'reduction',
#    'risk',
#    'risks',
#    'stocks',
#    'systems',
#    'warning'},
#   'category_description_raw': 'disaster risk reduction activities (e.g. developing knowledge, natural risks cartography, legal norms for construction); early warning systems; emergency contingency stocks and contingency planning including preparations for forced displacement.',
#   'category_name': {'and', 'disaster', 'preparedness', 'prevention'},
#   'category_name_raw': 'disaster prevention and preparedness',
#   'sector_description': {'activities',
#    'and',
#    'cartography',
#    'construction',
#    'contingency',
#    'developing',
#    'disaster',
#    'displacement',
#    'e',
#    'early',
#    'emergency',
#    'for',
#    'forced',
#    'g',
#    'including',
#    'knowledge',
#    'legal',
#    'natural',
#    'norms',
#    'planning',
#    'preparations',
#    'reduction',
#    'risk',
#    'risks',
#    'stocks',
#    'systems',
#    'warning'},
#   'sector_description_raw': 'disaster risk reduction activities (e.g. developing knowledge, natural risks cartography, legal norms for construction); early warning systems; emergency contingency stocks and contingency planning including preparations for forced displacement.',
#   'sector_name': {'and', 'disaster', 'preparedness', 'prevention'},
#   'sector_name_raw': 'disaster prevention and preparedness'},
#  '91010': {'category_description': set(),
#   'category_description_raw': '',
#   'category_name': {'administrative', 'costs', 'donors', 'of'},
#   'category_name_raw': 'administrative costs of donors',
#   'sector_description': set(),
#   'sector_description_raw': '',
#   'sector_name': {'administrative', 'allocable', 'costs', 'non', 'sector'},
#   'sector_name_raw': 'administrative costs (non-sector allocable)'},
#  '92010': {'category_description': {'country', 'donor', 'in', 'the'},
#   'category_description_raw': 'in the donor country.',
#   'category_name': {'governmental',
#    'ngos',
#    'non',
#    'organisations',
#    'support',
#    'to'},
#   'category_name_raw': 'support to non- governmental organisations (ngos)',
#   'sector_description': {'country', 'donor', 'in', 'the'},
#   'sector_description_raw': 'in the donor country.',
#   'sector_name': {'national', 'ngos', 'support', 'to'},
#   'sector_name_raw': 'support to national ngos'},
#  '92020': {'category_description': {'country', 'donor', 'in', 'the'},
#   'category_description_raw': 'in the donor country.',
#   'category_name': {'governmental',
#    'ngos',
#    'non',
#    'organisations',
#    'support',
#    'to'},
#   'category_name_raw': 'support to non- governmental organisations (ngos)',
#   'sector_description': set(),
#   'sector_description_raw': '',
#   'sector_name': {'international', 'ngos', 'support', 'to'},
#   'sector_name_raw': 'support to international ngos'},
#  '92030': {'category_description': {'country', 'donor', 'in', 'the'},
#   'category_description_raw': 'in the donor country.',
#   'category_name': {'governmental',
#    'ngos',
#    'non',
#    'organisations',
#    'support',
#    'to'},
#   'category_name_raw': 'support to non- governmental organisations (ngos)',
#   'sector_description': {'country', 'in', 'or', 'recipient', 'region', 'the'},
#   'sector_description_raw': 'in the recipient country or region.',
#   'sector_name': {'and', 'local', 'ngos', 'regional', 'support', 'to'},
#   'sector_name_raw': 'support to local and regional ngos'},
#  '93010': {'category_description': set(),
#   'category_description_raw': '',
#   'category_name': {'countries', 'donor', 'in', 'refugees'},
#   'category_name_raw': 'refugees in donor countries',
#   'sector_description': set(),
#   'sector_description_raw': '',
#   'sector_name': {'allocable',
#    'countries',
#    'donor',
#    'in',
#    'non',
#    'refugees',
#    'sector'},
#   'sector_name_raw': 'refugees in donor countries (non-sector allocable)'},
#  '99810': {'category_description': {'assistance',
#    'be',
#    'contributions',
#    'development',
#    'general',
#    'included',
#    'of',
#    'programme',
#    'recipient',
#    'should',
#    'the',
#    'to',
#    'under'},
#   'category_description_raw': 'contributions to general development of the recipient should be included under programme assistance (51010).',
#   'category_name': {'unallocated', 'unspecified'},
#   'category_name_raw': 'unallocated/ unspecified',
#   'sector_description': {'assistance',
#    'be',
#    'contributions',
#    'development',
#    'general',
#    'included',
#    'of',
#    'programme',
#    'recipient',
#    'should',
#    'the',
#    'to',
#    'under'},
#   'sector_description_raw': 'contributions to general development of the recipient should be included under programme assistance (51010).',
#   'sector_name': {'not', 'sectors', 'specified'},
#   'sector_name_raw': 'sectors not specified'},
#  '99820': {'category_description': {'assistance',
#    'be',
#    'contributions',
#    'development',
#    'general',
#    'included',
#    'of',
#    'programme',
#    'recipient',
#    'should',
#    'the',
#    'to',
#    'under'},
#   'category_description_raw': 'contributions to general development of the recipient should be included under programme assistance (51010).',
#   'category_name': {'unallocated', 'unspecified'},
#   'category_name_raw': 'unallocated/ unspecified',
#   'sector_description': {'awareness',
#    'brochures',
#    'co',
#    'country',
#    'development',
#    'donor',
#    'etc',
#    'for',
#    'heightened',
#    'in',
#    'interest',
#    'lectures',
#    'operation',
#    'projects',
#    'research',
#    'special',
#    'spending'},
#   'sector_description_raw': 'spending in donor country for heightened awareness/interest in development co-operation (brochures, lectures, special research projects, etc.).',
#   'sector_name': {'allocable',
#    'awareness',
#    'development',
#    'non',
#    'of',
#    'promotion',
#    'sector'},
#   'sector_name_raw': 'promotion of development awareness (non-sector allocable)'}}

# %%
searchable_policy_markers = {}

for code, policy_marker in policy_markers.items():
    policy_marker_data = {}

    add_attribute(policy_marker, 'name', policy_marker_data, 'name')

    searchable_policy_markers[code] = policy_marker_data

# %%
searchable_policy_markers
# Out:
# {'1': {'name': {'equality', 'gender'}, 'name_raw': 'gender equality'},
#  '2': {'name': {'aid', 'environment', 'to'}, 'name_raw': 'aid to environment'},
#  '3': {'name': {'development', 'good', 'governance', 'participatory'},
#   'name_raw': 'participatory development/good governance'},
#  '4': {'name': {'development', 'trade'}, 'name_raw': 'trade development'},
#  '5': {'name': {'aid',
#    'biological',
#    'convention',
#    'diversity',
#    'objectives',
#    'of',
#    'on',
#    'targeting',
#    'the'},
#   'name_raw': 'aid targeting the objectives of the convention on biological diversity'},
#  '6': {'name': {'aid',
#    'change',
#    'climate',
#    'convention',
#    'framework',
#    'mitigation',
#    'objectives',
#    'of',
#    'on',
#    'targeting',
#    'the'},
#   'name_raw': 'aid targeting the objectives of the framework convention on climate change - mitigation'},
#  '7': {'name': {'adaptation',
#    'aid',
#    'change',
#    'climate',
#    'convention',
#    'framework',
#    'objectives',
#    'of',
#    'on',
#    'targeting',
#    'the'},
#   'name_raw': 'aid targeting the objectives of the framework convention on climate change - adaptation'},
#  '8': {'name': {'aid',
#    'combat',
#    'convention',
#    'desertification',
#    'objectives',
#    'of',
#    'targeting',
#    'the',
#    'to'},
#   'name_raw': 'aid targeting the objectives of the convention to combat desertification'},
#  '9': {'name': {'and',
#    'child',
#    'health',
#    'maternal',
#    'newborn',
#    'reproductive',
#    'rmnch'},
#   'name_raw': 'reproductive, maternal, newborn and child health (rmnch)'}}

# %% [markdown]
# # Save the Data

# %%
with open('codelist_sectors.pickle', 'wb') as f:
    pickle.dump(searchable_sectors, f)

# %%
with open('codelist_policy_markers.pickle', 'wb') as f:
    pickle.dump(searchable_policy_markers, f)

# %%
# !tar -cf codelist.tar codelist_*
# !gzip codelist.tar
# !aws s3 cp codelist.tar.gz s3://mdang.w210/ --acl public-read
# Out:
# upload: ./codelist.tar.gz to s3://mdang.w210/codelist.tar.gz
